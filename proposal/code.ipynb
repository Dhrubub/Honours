# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

import os
from PIL import Image
import random

# %%
def resize_image(image):
    IMG_SIZE = 224
    image = tf.cast(image, tf.float32)
    image = (image/255)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image

# %%
full_data = []
combined_data = 'datasets/Combined Data'
three_classes = 'datasets/Tube_Effusion_Normal - 11_7_19'

data_path = three_classes
class_names = [x for x in os.listdir(data_path) if os.path.isdir(data_path + '/' + x)]
print(class_names)
class_dict = {}
for i, name in enumerate(class_names):
    class_dict[name] = i
print(class_dict)

def get_data(): 
    path = data_path
    for di in os.listdir(path):
        dirpath = path+"/"+di
        if (os.path.isdir(dirpath)):

            image_files = [x for x in os.listdir(dirpath) if (x[-4:] == "jpeg" or x[-3:] == "png" or x[-3:] == 'jpg')]

            for img in image_files:
                image = Image.open(dirpath+"/"+img)
                data = np.asarray(image)
                data = resize_image(data)
                image_tuple = np.array([data, class_dict[di]])
                full_data.append(image_tuple)


get_data()
full_data = np.array(full_data)

random.shuffle(full_data)

full_data.shape
# Out:
# ['Tube', 'Effusion', 'Normal']
# {'Tube': 0, 'Effusion': 1, 'Normal': 2}
# /var/folders/84/c6fx1p654h5cgl4xrm3kgys80000gn/T/ipykernel_16033/2941472138.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   image_tuple = np.array([data, class_dict[di]])
# (454, 2)

# %%
X_full = np.array([x[0] for x in full_data])
y_full = np.array([x[1] for x in full_data])

print(X_full[0].shape)
# Out:
# (224, 224, 3)

# %%
split = int(0.7*len(X_full))
X_train = X_full[:split]
X_test = X_full[split:]

y_train = y_full[:split]
y_test = y_full[split:]

# %%
from keras_cv_attention_models import beit
# Will download and load pretrained imagenet21k-ft1k weights.
mm = beit.BeitBasePatch16(input_shape=(224, 224, 3), pretrained="imagenet21k-ft1k")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/beit/beit_base_patch16_224_imagenet21k-ft1k.h5
# 346849280/346843944 [==============================] - 55s 0us/step
# 346857472/346843944 [==============================] - 55s 0us/step
# >>>> Load pretrained from: /Users/dhruv/.keras/models/beit_base_patch16_224_imagenet21k-ft1k.h5

# %%
mm.summary()
# Out:
# Model: "beit_large_patch16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 14, 14, 1024  787456      ['input_1[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 196, 1024)    0           ['stem_conv[0][0]']
#
#  cls_token (ClassToken)         (None, 197, 1024)    1024        ['reshape[0][0]']
#
#  block0_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['cls_token[0][0]']
#  tion)
#
#  block0_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block0_attn_ln[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 197, 3072)    0           ['block0_attn_qkv[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 197, 1024),  0           ['tf.reshape[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block0_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split[0][0]']
#  yer)
#
#  tf.reshape_1 (TFOpLambda)      (None, 197, 16, 64)  0           ['block0_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose (TFOpLa  (None, 16, 197, 64)  0          ['tf.reshape_1[0][0]']
#  mbda)
#
#  tf.reshape_2 (TFOpLambda)      (None, 197, 16, 64)  0           ['tf.split[0][1]']
#
#  tf.math.multiply (TFOpLambda)  (None, 16, 197, 64)  0           ['tf.compat.v1.transpose[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_2[0][0]']
#  Lambda)
#
#  lambda (Lambda)                (None, 16, 197, 197  0           ['tf.math.multiply[0][0]',
#                                 )                                 'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  block0_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split[0][2]']
#  yer)
#
#  block0_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_3 (TFOpLambda)      (None, 197, 16, 64)  0           ['block0_attn_value_bias[0][0]']
#
#  block0_attn_attention_scores (  (None, 16, 197, 197  0          ['block0_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_3[0][0]']
#  Lambda)
#
#  lambda_1 (Lambda)              (None, 16, 197, 64)  0           ['block0_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 197, 16, 64)  0          ['lambda_1[0][0]']
#  Lambda)
#
#  tf.reshape_4 (TFOpLambda)      (None, 197, 1024)    0           ['tf.compat.v1.transpose_3[0][0]'
#                                                                  ]
#
#  block0_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_4[0][0]']
#
#  block0_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block0_attn_output[0][0]']
#  ne)
#
#  block0_attn_out (Add)          (None, 197, 1024)    0           ['cls_token[0][0]',
#                                                                   'block0_attn_gamma[0][0]']
#
#  block0_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block0_attn_out[0][0]']
#  ion)
#
#  block0_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block0_mlp_ln[0][0]']
#
#  block0_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block0_mlp_dense_1[0][0]']
#  n)
#
#  block0_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block0_mlp_gelugelu[0][0]']
#
#  block0_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block0_mlp_dense_2[0][0]']
#  e)
#
#  block0_mlp_output (Add)        (None, 197, 1024)    0           ['block0_attn_out[0][0]',
#                                                                   'block0_mlp_gamma[0][0]']
#
#  block1_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block0_mlp_output[0][0]']
#  tion)
#
#  block1_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block1_attn_ln[0][0]']
#
#  tf.reshape_5 (TFOpLambda)      (None, 197, 3072)    0           ['block1_attn_qkv[0][0]']
#
#  tf.split_1 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_5[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block1_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_1[0][0]']
#  yer)
#
#  tf.reshape_6 (TFOpLambda)      (None, 197, 16, 64)  0           ['block1_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_6[0][0]']
#  Lambda)
#
#  tf.reshape_7 (TFOpLambda)      (None, 197, 16, 64)  0           ['tf.split_1[0][1]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_4[0][0]'
#  )                                                               ]
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_7[0][0]']
#  Lambda)
#
#  lambda_2 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_1[0][0]',
#                                 )                                 'tf.compat.v1.transpose_5[0][0]'
#                                                                  ]
#
#  block1_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_1[0][2]']
#  yer)
#
#  block1_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_2[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_8 (TFOpLambda)      (None, 197, 16, 64)  0           ['block1_attn_value_bias[0][0]']
#
#  block1_attn_attention_scores (  (None, 16, 197, 197  0          ['block1_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_6 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_8[0][0]']
#  Lambda)
#
#  lambda_3 (Lambda)              (None, 16, 197, 64)  0           ['block1_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_6[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_7 (TFOp  (None, 197, 16, 64)  0          ['lambda_3[0][0]']
#  Lambda)
#
#  tf.reshape_9 (TFOpLambda)      (None, 197, 1024)    0           ['tf.compat.v1.transpose_7[0][0]'
#                                                                  ]
#
#  block1_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_9[0][0]']
#
#  block1_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block1_attn_output[0][0]']
#  ne)
#
#  block1_attn_out (Add)          (None, 197, 1024)    0           ['block0_mlp_output[0][0]',
#                                                                   'block1_attn_gamma[0][0]']
#
#  block1_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block1_attn_out[0][0]']
#  ion)
#
#  block1_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block1_mlp_ln[0][0]']
#
#  block1_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block1_mlp_dense_1[0][0]']
#  n)
#
#  block1_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block1_mlp_gelugelu[0][0]']
#  block1_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block1_mlp_dense_2[0][0]']
#  e)
#
#  block1_mlp_output (Add)        (None, 197, 1024)    0           ['block1_attn_out[0][0]',
#                                                                   'block1_mlp_gamma[0][0]']
#
#  block2_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block1_mlp_output[0][0]']
#  tion)
#
#  block2_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block2_attn_ln[0][0]']
#
#  tf.reshape_10 (TFOpLambda)     (None, 197, 3072)    0           ['block2_attn_qkv[0][0]']
#
#  tf.split_2 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_10[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block2_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_2[0][0]']
#  yer)
#
#  tf.reshape_11 (TFOpLambda)     (None, 197, 16, 64)  0           ['block2_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_8 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_11[0][0]']
#  Lambda)
#
#  tf.reshape_12 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_2[0][1]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_8[0][0]'
#  )                                                               ]
#
#  tf.compat.v1.transpose_9 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_12[0][0]']
#  Lambda)
#
#  lambda_4 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_2[0][0]',
#                                 )                                 'tf.compat.v1.transpose_9[0][0]'
#                                                                  ]
#
#  block2_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_2[0][2]']
#  yer)
#
#  block2_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_4[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_13 (TFOpLambda)     (None, 197, 16, 64)  0           ['block2_attn_value_bias[0][0]']
#
#  block2_attn_attention_scores (  (None, 16, 197, 197  0          ['block2_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_10 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_13[0][0]']
#  pLambda)
#
#  lambda_5 (Lambda)              (None, 16, 197, 64)  0           ['block2_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_10[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_11 (TFO  (None, 197, 16, 64)  0          ['lambda_5[0][0]']
#  pLambda)
#
#  tf.reshape_14 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_11[0][0]
#                                                                  ']
#
#  block2_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_14[0][0]']
#
#  block2_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block2_attn_output[0][0]']
#  ne)
#
#  block2_attn_out (Add)          (None, 197, 1024)    0           ['block1_mlp_output[0][0]',
#                                                                   'block2_attn_gamma[0][0]']
#
#  block2_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block2_attn_out[0][0]']
#  ion)
#
#  block2_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block2_mlp_ln[0][0]']
#
#  block2_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block2_mlp_dense_1[0][0]']
#  n)
#
#  block2_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block2_mlp_gelugelu[0][0]']
#
#  block2_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block2_mlp_dense_2[0][0]']
#  e)
#  block2_mlp_output (Add)        (None, 197, 1024)    0           ['block2_attn_out[0][0]',
#                                                                   'block2_mlp_gamma[0][0]']
#
#  block3_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block2_mlp_output[0][0]']
#  tion)
#
#  block3_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block3_attn_ln[0][0]']
#
#  tf.reshape_15 (TFOpLambda)     (None, 197, 3072)    0           ['block3_attn_qkv[0][0]']
#
#  tf.split_3 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_15[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block3_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_3[0][0]']
#  yer)
#
#  tf.reshape_16 (TFOpLambda)     (None, 197, 16, 64)  0           ['block3_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_12 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_16[0][0]']
#  pLambda)
#
#  tf.reshape_17 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_3[0][1]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_12[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_13 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_17[0][0]']
#  pLambda)
#
#  lambda_6 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_3[0][0]',
#                                 )                                 'tf.compat.v1.transpose_13[0][0]
#                                                                  ']
#
#  block3_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_3[0][2]']
#  yer)
#
#  block3_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_6[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_18 (TFOpLambda)     (None, 197, 16, 64)  0           ['block3_attn_value_bias[0][0]']
#
#  block3_attn_attention_scores (  (None, 16, 197, 197  0          ['block3_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_14 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_18[0][0]']
#  pLambda)
#
#  lambda_7 (Lambda)              (None, 16, 197, 64)  0           ['block3_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_14[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_15 (TFO  (None, 197, 16, 64)  0          ['lambda_7[0][0]']
#  pLambda)
#
#  tf.reshape_19 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_15[0][0]
#                                                                  ']
#
#  block3_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_19[0][0]']
#
#  block3_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block3_attn_output[0][0]']
#  ne)
#
#  block3_attn_out (Add)          (None, 197, 1024)    0           ['block2_mlp_output[0][0]',
#                                                                   'block3_attn_gamma[0][0]']
#
#  block3_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block3_attn_out[0][0]']
#  ion)
#
#  block3_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block3_mlp_ln[0][0]']
#
#  block3_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block3_mlp_dense_1[0][0]']
#  n)
#
#  block3_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block3_mlp_gelugelu[0][0]']
#
#  block3_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block3_mlp_dense_2[0][0]']
#  e)
#
#  block3_mlp_output (Add)        (None, 197, 1024)    0           ['block3_attn_out[0][0]',
#                                                                   'block3_mlp_gamma[0][0]']
#  block4_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block3_mlp_output[0][0]']
#  tion)
#
#  block4_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block4_attn_ln[0][0]']
#
#  tf.reshape_20 (TFOpLambda)     (None, 197, 3072)    0           ['block4_attn_qkv[0][0]']
#
#  tf.split_4 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_20[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block4_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_4[0][0]']
#  yer)
#
#  tf.reshape_21 (TFOpLambda)     (None, 197, 16, 64)  0           ['block4_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_16 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_21[0][0]']
#  pLambda)
#
#  tf.reshape_22 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_4[0][1]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_16[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_17 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_22[0][0]']
#  pLambda)
#
#  lambda_8 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_4[0][0]',
#                                 )                                 'tf.compat.v1.transpose_17[0][0]
#                                                                  ']
#
#  block4_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_4[0][2]']
#  yer)
#
#  block4_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_8[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_23 (TFOpLambda)     (None, 197, 16, 64)  0           ['block4_attn_value_bias[0][0]']
#
#  block4_attn_attention_scores (  (None, 16, 197, 197  0          ['block4_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_18 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_23[0][0]']
#  pLambda)
#
#  lambda_9 (Lambda)              (None, 16, 197, 64)  0           ['block4_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_18[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_19 (TFO  (None, 197, 16, 64)  0          ['lambda_9[0][0]']
#  pLambda)
#
#  tf.reshape_24 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_19[0][0]
#                                                                  ']
#
#  block4_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_24[0][0]']
#
#  block4_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block4_attn_output[0][0]']
#  ne)
#
#  block4_attn_out (Add)          (None, 197, 1024)    0           ['block3_mlp_output[0][0]',
#                                                                   'block4_attn_gamma[0][0]']
#
#  block4_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block4_attn_out[0][0]']
#  ion)
#
#  block4_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block4_mlp_ln[0][0]']
#
#  block4_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block4_mlp_dense_1[0][0]']
#  n)
#
#  block4_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block4_mlp_gelugelu[0][0]']
#
#  block4_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block4_mlp_dense_2[0][0]']
#  e)
#
#  block4_mlp_output (Add)        (None, 197, 1024)    0           ['block4_attn_out[0][0]',
#                                                                   'block4_mlp_gamma[0][0]']
#
#  block5_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block4_mlp_output[0][0]']
#  tion)
#  block5_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block5_attn_ln[0][0]']
#
#  tf.reshape_25 (TFOpLambda)     (None, 197, 3072)    0           ['block5_attn_qkv[0][0]']
#
#  tf.split_5 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_25[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block5_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_5[0][0]']
#  yer)
#
#  tf.reshape_26 (TFOpLambda)     (None, 197, 16, 64)  0           ['block5_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_20 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_26[0][0]']
#  pLambda)
#
#  tf.reshape_27 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_5[0][1]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_20[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_21 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_27[0][0]']
#  pLambda)
#
#  lambda_10 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_5[0][0]',
#                                 )                                 'tf.compat.v1.transpose_21[0][0]
#                                                                  ']
#
#  block5_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_5[0][2]']
#  yer)
#
#  block5_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_10[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_28 (TFOpLambda)     (None, 197, 16, 64)  0           ['block5_attn_value_bias[0][0]']
#
#  block5_attn_attention_scores (  (None, 16, 197, 197  0          ['block5_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_22 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_28[0][0]']
#  pLambda)
#
#  lambda_11 (Lambda)             (None, 16, 197, 64)  0           ['block5_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_22[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_23 (TFO  (None, 197, 16, 64)  0          ['lambda_11[0][0]']
#  pLambda)
#
#  tf.reshape_29 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_23[0][0]
#                                                                  ']
#
#  block5_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_29[0][0]']
#
#  block5_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block5_attn_output[0][0]']
#  ne)
#
#  block5_attn_out (Add)          (None, 197, 1024)    0           ['block4_mlp_output[0][0]',
#                                                                   'block5_attn_gamma[0][0]']
#
#  block5_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block5_attn_out[0][0]']
#  ion)
#
#  block5_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block5_mlp_ln[0][0]']
#
#  block5_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block5_mlp_dense_1[0][0]']
#  n)
#
#  block5_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block5_mlp_gelugelu[0][0]']
#
#  block5_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block5_mlp_dense_2[0][0]']
#  e)
#
#  block5_mlp_output (Add)        (None, 197, 1024)    0           ['block5_attn_out[0][0]',
#                                                                   'block5_mlp_gamma[0][0]']
# ...
#  ayer)
#
#  tf.reshape_111 (TFOpLambda)    (None, 197, 16, 64)  0           ['block22_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_88 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_111[0][0]']
#  pLambda)
#
#  tf.reshape_112 (TFOpLambda)    (None, 197, 16, 64)  0           ['tf.split_22[0][1]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_88[0][0]
#  a)                                                              ']
#
#  tf.compat.v1.transpose_89 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_112[0][0]']
#  pLambda)
#
#  lambda_44 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_22[0][0]',
#                                 )                                 'tf.compat.v1.transpose_89[0][0]
#                                                                  ']
#
#  block22_attn_value_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_22[0][2]']
#  ayer)
#
#  block22_attn_pos_emb (MultiHea  (None, 16, 197, 197  11712      ['lambda_44[0][0]']
#  dRelativePositionalEmbedding)  )
#
#  tf.reshape_113 (TFOpLambda)    (None, 197, 16, 64)  0           ['block22_attn_value_bias[0][0]']
#
#  block22_attn_attention_scores   (None, 16, 197, 197  0          ['block22_attn_pos_emb[0][0]']
#  (Softmax)                      )
#
#  tf.compat.v1.transpose_90 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_113[0][0]']
#  pLambda)
#
#  lambda_45 (Lambda)             (None, 16, 197, 64)  0           ['block22_attn_attention_scores[0
#                                                                  ][0]',
#                                                                   'tf.compat.v1.transpose_90[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_91 (TFO  (None, 197, 16, 64)  0          ['lambda_45[0][0]']
#  pLambda)
#
#  tf.reshape_114 (TFOpLambda)    (None, 197, 1024)    0           ['tf.compat.v1.transpose_91[0][0]
#                                                                  ']
#
#  block22_attn_output (Dense)    (None, 197, 1024)    1049600     ['tf.reshape_114[0][0]']
#
#  block22_attn_gamma (ChannelAff  (None, 197, 1024)   1024        ['block22_attn_output[0][0]']
#  ine)
#
#  block22_attn_out (Add)         (None, 197, 1024)    0           ['block21_mlp_output[0][0]',
#                                                                   'block22_attn_gamma[0][0]']
#
#  block22_mlp_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block22_attn_out[0][0]']
#  tion)
#
#  block22_mlp_dense_1 (Dense)    (None, 197, 4096)    4198400     ['block22_mlp_ln[0][0]']
#
#  block22_mlp_gelugelu (Activati  (None, 197, 4096)   0           ['block22_mlp_dense_1[0][0]']
#  on)
#
#  block22_mlp_dense_2 (Dense)    (None, 197, 1024)    4195328     ['block22_mlp_gelugelu[0][0]']
#
#  block22_mlp_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block22_mlp_dense_2[0][0]']
#  ne)
#
#  block22_mlp_output (Add)       (None, 197, 1024)    0           ['block22_attn_out[0][0]',
#                                                                   'block22_mlp_gamma[0][0]']
#
#  block23_attn_ln (LayerNormaliz  (None, 197, 1024)   2048        ['block22_mlp_output[0][0]']
#  ation)
#
#  block23_attn_qkv (Dense)       (None, 197, 3072)    3145728     ['block23_attn_ln[0][0]']
#
#  tf.reshape_115 (TFOpLambda)    (None, 197, 3072)    0           ['block23_attn_qkv[0][0]']
#
#  tf.split_23 (TFOpLambda)       [(None, 197, 1024),  0           ['tf.reshape_115[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block23_attn_query_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_23[0][0]']
#  ayer)
#
#  tf.reshape_116 (TFOpLambda)    (None, 197, 16, 64)  0           ['block23_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_92 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_116[0][0]']
#  pLambda)
#
#  tf.reshape_117 (TFOpLambda)    (None, 197, 16, 64)  0           ['tf.split_23[0][1]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_92[0][0]
#  a)                                                              ']
#
#  tf.compat.v1.transpose_93 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_117[0][0]']
#  pLambda)
#
#  lambda_46 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_23[0][0]',
#                                 )                                 'tf.compat.v1.transpose_93[0][0]
#                                                                  ']
#
#  block23_attn_value_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_23[0][2]']
#  ayer)
#
#  block23_attn_pos_emb (MultiHea  (None, 16, 197, 197  11712      ['lambda_46[0][0]']
#  dRelativePositionalEmbedding)  )
#
#  tf.reshape_118 (TFOpLambda)    (None, 197, 16, 64)  0           ['block23_attn_value_bias[0][0]']
#
#  block23_attn_attention_scores   (None, 16, 197, 197  0          ['block23_attn_pos_emb[0][0]']
#  (Softmax)                      )
#
#  tf.compat.v1.transpose_94 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_118[0][0]']
#  pLambda)
#
#  lambda_47 (Lambda)             (None, 16, 197, 64)  0           ['block23_attn_attention_scores[0
#                                                                  ][0]',
#                                                                   'tf.compat.v1.transpose_94[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_95 (TFO  (None, 197, 16, 64)  0          ['lambda_47[0][0]']
#  pLambda)
#
#  tf.reshape_119 (TFOpLambda)    (None, 197, 1024)    0           ['tf.compat.v1.transpose_95[0][0]
#                                                                  ']
#
#  block23_attn_output (Dense)    (None, 197, 1024)    1049600     ['tf.reshape_119[0][0]']
#
#  block23_attn_gamma (ChannelAff  (None, 197, 1024)   1024        ['block23_attn_output[0][0]']
#  ine)
#
#  block23_attn_out (Add)         (None, 197, 1024)    0           ['block22_mlp_output[0][0]',
#                                                                   'block23_attn_gamma[0][0]']
#
#  block23_mlp_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block23_attn_out[0][0]']
#  tion)
#
#  block23_mlp_dense_1 (Dense)    (None, 197, 4096)    4198400     ['block23_mlp_ln[0][0]']
#
#  block23_mlp_gelugelu (Activati  (None, 197, 4096)   0           ['block23_mlp_dense_1[0][0]']
#  on)
#
#  block23_mlp_dense_2 (Dense)    (None, 197, 1024)    4195328     ['block23_mlp_gelugelu[0][0]']
#
#  block23_mlp_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block23_mlp_dense_2[0][0]']
#  ne)
#
#  block23_mlp_output (Add)       (None, 197, 1024)    0           ['block23_attn_out[0][0]',
#                                                                   'block23_mlp_gamma[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 196, 1024)   0           ['block23_mlp_output[0][0]']
#  ingOpLambda)
#
#  tf.math.reduce_mean (TFOpLambd  (None, 1024)        0           ['tf.__operators__.getitem[0][0]'
#  a)                                                              ]
#
#  out_ln (LayerNormalization)    (None, 1024)         2048        ['tf.math.reduce_mean[0][0]']
#
#  predictions (Dense)            (None, 1000)         1025000     ['out_ln[0][0]']
#
# ==================================================================================================
# Total params: 304,430,568
# Trainable params: 304,430,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x = mm.layers[-2].output
print(x)
output = keras.layers.Dense(units=len(class_names), activation="softmax")(x)

model = keras.models.Model(inputs=mm.input, outputs=output)
for layer in model.layers: layer.trainable = True
for layer in model.layers[:-10]: layer.trainable = False

model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1024), dtype=tf.float32, name=None), name='out_ln/batchnorm/add_1:0', description="created by layer 'out_ln'")
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 14, 14, 1024  787456      ['input_1[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 196, 1024)    0           ['stem_conv[0][0]']
#
#  cls_token (ClassToken)         (None, 197, 1024)    1024        ['reshape[0][0]']
#
#  block0_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['cls_token[0][0]']
#  tion)
#
#  block0_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block0_attn_ln[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 197, 3072)    0           ['block0_attn_qkv[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 197, 1024),  0           ['tf.reshape[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block0_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split[0][0]']
#  yer)
#
#  tf.reshape_1 (TFOpLambda)      (None, 197, 16, 64)  0           ['block0_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose (TFOpLa  (None, 16, 197, 64)  0          ['tf.reshape_1[0][0]']
#  mbda)
#
#  tf.reshape_2 (TFOpLambda)      (None, 197, 16, 64)  0           ['tf.split[0][1]']
#
#  tf.math.multiply (TFOpLambda)  (None, 16, 197, 64)  0           ['tf.compat.v1.transpose[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_2[0][0]']
#  Lambda)
#
#  lambda (Lambda)                (None, 16, 197, 197  0           ['tf.math.multiply[0][0]',
#                                 )                                 'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  block0_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split[0][2]']
#  yer)
#
#  block0_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_3 (TFOpLambda)      (None, 197, 16, 64)  0           ['block0_attn_value_bias[0][0]']
#
#  block0_attn_attention_scores (  (None, 16, 197, 197  0          ['block0_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_3[0][0]']
#  Lambda)
#
#  lambda_1 (Lambda)              (None, 16, 197, 64)  0           ['block0_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 197, 16, 64)  0          ['lambda_1[0][0]']
#  Lambda)
#
#  tf.reshape_4 (TFOpLambda)      (None, 197, 1024)    0           ['tf.compat.v1.transpose_3[0][0]'
#                                                                  ]
#
#  block0_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_4[0][0]']
#
#  block0_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block0_attn_output[0][0]']
#  ne)
#
#  block0_attn_out (Add)          (None, 197, 1024)    0           ['cls_token[0][0]',
#                                                                   'block0_attn_gamma[0][0]']
#
#  block0_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block0_attn_out[0][0]']
#  ion)
#
#  block0_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block0_mlp_ln[0][0]']
#  block0_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block0_mlp_dense_1[0][0]']
#  n)
#
#  block0_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block0_mlp_gelugelu[0][0]']
#
#  block0_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block0_mlp_dense_2[0][0]']
#  e)
#
#  block0_mlp_output (Add)        (None, 197, 1024)    0           ['block0_attn_out[0][0]',
#                                                                   'block0_mlp_gamma[0][0]']
#
#  block1_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block0_mlp_output[0][0]']
#  tion)
#
#  block1_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block1_attn_ln[0][0]']
#
#  tf.reshape_5 (TFOpLambda)      (None, 197, 3072)    0           ['block1_attn_qkv[0][0]']
#
#  tf.split_1 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_5[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block1_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_1[0][0]']
#  yer)
#
#  tf.reshape_6 (TFOpLambda)      (None, 197, 16, 64)  0           ['block1_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_6[0][0]']
#  Lambda)
#
#  tf.reshape_7 (TFOpLambda)      (None, 197, 16, 64)  0           ['tf.split_1[0][1]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_4[0][0]'
#  )                                                               ]
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_7[0][0]']
#  Lambda)
#
#  lambda_2 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_1[0][0]',
#                                 )                                 'tf.compat.v1.transpose_5[0][0]'
#                                                                  ]
#
#  block1_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_1[0][2]']
#  yer)
#
#  block1_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_2[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_8 (TFOpLambda)      (None, 197, 16, 64)  0           ['block1_attn_value_bias[0][0]']
#
#  block1_attn_attention_scores (  (None, 16, 197, 197  0          ['block1_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_6 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_8[0][0]']
#  Lambda)
#
#  lambda_3 (Lambda)              (None, 16, 197, 64)  0           ['block1_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_6[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_7 (TFOp  (None, 197, 16, 64)  0          ['lambda_3[0][0]']
#  Lambda)
#
#  tf.reshape_9 (TFOpLambda)      (None, 197, 1024)    0           ['tf.compat.v1.transpose_7[0][0]'
#                                                                  ]
#
#  block1_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_9[0][0]']
#
#  block1_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block1_attn_output[0][0]']
#  ne)
#
#  block1_attn_out (Add)          (None, 197, 1024)    0           ['block0_mlp_output[0][0]',
#                                                                   'block1_attn_gamma[0][0]']
#
#  block1_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block1_attn_out[0][0]']
#  ion)
#
#  block1_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block1_mlp_ln[0][0]']
#
#  block1_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block1_mlp_dense_1[0][0]']
#  n)
#  block1_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block1_mlp_gelugelu[0][0]']
#
#  block1_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block1_mlp_dense_2[0][0]']
#  e)
#
#  block1_mlp_output (Add)        (None, 197, 1024)    0           ['block1_attn_out[0][0]',
#                                                                   'block1_mlp_gamma[0][0]']
#
#  block2_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block1_mlp_output[0][0]']
#  tion)
#
#  block2_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block2_attn_ln[0][0]']
#
#  tf.reshape_10 (TFOpLambda)     (None, 197, 3072)    0           ['block2_attn_qkv[0][0]']
#
#  tf.split_2 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_10[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block2_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_2[0][0]']
#  yer)
#
#  tf.reshape_11 (TFOpLambda)     (None, 197, 16, 64)  0           ['block2_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_8 (TFOp  (None, 16, 197, 64)  0          ['tf.reshape_11[0][0]']
#  Lambda)
#
#  tf.reshape_12 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_2[0][1]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_8[0][0]'
#  )                                                               ]
#
#  tf.compat.v1.transpose_9 (TFOp  (None, 16, 64, 197)  0          ['tf.reshape_12[0][0]']
#  Lambda)
#
#  lambda_4 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_2[0][0]',
#                                 )                                 'tf.compat.v1.transpose_9[0][0]'
#                                                                  ]
#
#  block2_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_2[0][2]']
#  yer)
#
#  block2_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_4[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_13 (TFOpLambda)     (None, 197, 16, 64)  0           ['block2_attn_value_bias[0][0]']
#
#  block2_attn_attention_scores (  (None, 16, 197, 197  0          ['block2_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_10 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_13[0][0]']
#  pLambda)
#
#  lambda_5 (Lambda)              (None, 16, 197, 64)  0           ['block2_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_10[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_11 (TFO  (None, 197, 16, 64)  0          ['lambda_5[0][0]']
#  pLambda)
#
#  tf.reshape_14 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_11[0][0]
#                                                                  ']
#
#  block2_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_14[0][0]']
#
#  block2_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block2_attn_output[0][0]']
#  ne)
#
#  block2_attn_out (Add)          (None, 197, 1024)    0           ['block1_mlp_output[0][0]',
#                                                                   'block2_attn_gamma[0][0]']
#
#  block2_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block2_attn_out[0][0]']
#  ion)
#
#  block2_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block2_mlp_ln[0][0]']
#
#  block2_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block2_mlp_dense_1[0][0]']
#  n)
#
#  block2_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block2_mlp_gelugelu[0][0]']
#
#  block2_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block2_mlp_dense_2[0][0]']
#  e)
#
#  block2_mlp_output (Add)        (None, 197, 1024)    0           ['block2_attn_out[0][0]',
#                                                                   'block2_mlp_gamma[0][0]']
#
#  block3_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block2_mlp_output[0][0]']
#  tion)
#
#  block3_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block3_attn_ln[0][0]']
#
#  tf.reshape_15 (TFOpLambda)     (None, 197, 3072)    0           ['block3_attn_qkv[0][0]']
#
#  tf.split_3 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_15[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block3_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_3[0][0]']
#  yer)
#
#  tf.reshape_16 (TFOpLambda)     (None, 197, 16, 64)  0           ['block3_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_12 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_16[0][0]']
#  pLambda)
#
#  tf.reshape_17 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_3[0][1]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_12[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_13 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_17[0][0]']
#  pLambda)
#
#  lambda_6 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_3[0][0]',
#                                 )                                 'tf.compat.v1.transpose_13[0][0]
#                                                                  ']
#
#  block3_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_3[0][2]']
#  yer)
#
#  block3_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_6[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_18 (TFOpLambda)     (None, 197, 16, 64)  0           ['block3_attn_value_bias[0][0]']
#
#  block3_attn_attention_scores (  (None, 16, 197, 197  0          ['block3_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_14 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_18[0][0]']
#  pLambda)
#
#  lambda_7 (Lambda)              (None, 16, 197, 64)  0           ['block3_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_14[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_15 (TFO  (None, 197, 16, 64)  0          ['lambda_7[0][0]']
#  pLambda)
#
#  tf.reshape_19 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_15[0][0]
#                                                                  ']
#
#  block3_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_19[0][0]']
#
#  block3_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block3_attn_output[0][0]']
#  ne)
#
#  block3_attn_out (Add)          (None, 197, 1024)    0           ['block2_mlp_output[0][0]',
#                                                                   'block3_attn_gamma[0][0]']
#
#  block3_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block3_attn_out[0][0]']
#  ion)
#
#  block3_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block3_mlp_ln[0][0]']
#
#  block3_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block3_mlp_dense_1[0][0]']
#  n)
#
#  block3_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block3_mlp_gelugelu[0][0]']
#
#  block3_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block3_mlp_dense_2[0][0]']
#  e)
#
#  block3_mlp_output (Add)        (None, 197, 1024)    0           ['block3_attn_out[0][0]',
#                                                                   'block3_mlp_gamma[0][0]']
#
#  block4_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block3_mlp_output[0][0]']
#  tion)
#
#  block4_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block4_attn_ln[0][0]']
#
#  tf.reshape_20 (TFOpLambda)     (None, 197, 3072)    0           ['block4_attn_qkv[0][0]']
#
#  tf.split_4 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_20[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block4_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_4[0][0]']
#  yer)
#
#  tf.reshape_21 (TFOpLambda)     (None, 197, 16, 64)  0           ['block4_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_16 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_21[0][0]']
#  pLambda)
#
#  tf.reshape_22 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_4[0][1]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_16[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_17 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_22[0][0]']
#  pLambda)
#
#  lambda_8 (Lambda)              (None, 16, 197, 197  0           ['tf.math.multiply_4[0][0]',
#                                 )                                 'tf.compat.v1.transpose_17[0][0]
#                                                                  ']
#
#  block4_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_4[0][2]']
#  yer)
#
#  block4_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_8[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_23 (TFOpLambda)     (None, 197, 16, 64)  0           ['block4_attn_value_bias[0][0]']
#
#  block4_attn_attention_scores (  (None, 16, 197, 197  0          ['block4_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_18 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_23[0][0]']
#  pLambda)
#
#  lambda_9 (Lambda)              (None, 16, 197, 64)  0           ['block4_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_18[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_19 (TFO  (None, 197, 16, 64)  0          ['lambda_9[0][0]']
#  pLambda)
#
#  tf.reshape_24 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_19[0][0]
#                                                                  ']
#
#  block4_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_24[0][0]']
#
#  block4_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block4_attn_output[0][0]']
#  ne)
#
#  block4_attn_out (Add)          (None, 197, 1024)    0           ['block3_mlp_output[0][0]',
#                                                                   'block4_attn_gamma[0][0]']
#
#  block4_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block4_attn_out[0][0]']
#  ion)
#
#  block4_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block4_mlp_ln[0][0]']
#
#  block4_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block4_mlp_dense_1[0][0]']
#  n)
#
#  block4_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block4_mlp_gelugelu[0][0]']
#
#  block4_mlp_gamma (ChannelAffin  (None, 197, 1024)   1024        ['block4_mlp_dense_2[0][0]']
#  e)
#
#  block4_mlp_output (Add)        (None, 197, 1024)    0           ['block4_attn_out[0][0]',
#                                                                   'block4_mlp_gamma[0][0]']
#
#  block5_attn_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block4_mlp_output[0][0]']
#  tion)
#
#  block5_attn_qkv (Dense)        (None, 197, 3072)    3145728     ['block5_attn_ln[0][0]']
#
#  tf.reshape_25 (TFOpLambda)     (None, 197, 3072)    0           ['block5_attn_qkv[0][0]']
#
#  tf.split_5 (TFOpLambda)        [(None, 197, 1024),  0           ['tf.reshape_25[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block5_attn_query_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_5[0][0]']
#  yer)
#
#  tf.reshape_26 (TFOpLambda)     (None, 197, 16, 64)  0           ['block5_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_20 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_26[0][0]']
#  pLambda)
#
#  tf.reshape_27 (TFOpLambda)     (None, 197, 16, 64)  0           ['tf.split_5[0][1]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_20[0][0]
#  )                                                               ']
#
#  tf.compat.v1.transpose_21 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_27[0][0]']
#  pLambda)
#
#  lambda_10 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_5[0][0]',
#                                 )                                 'tf.compat.v1.transpose_21[0][0]
#                                                                  ']
#
#  block5_attn_value_bias (BiasLa  (None, 197, 1024)   1024        ['tf.split_5[0][2]']
#  yer)
#
#  block5_attn_pos_emb (MultiHead  (None, 16, 197, 197  11712      ['lambda_10[0][0]']
#  RelativePositionalEmbedding)   )
#
#  tf.reshape_28 (TFOpLambda)     (None, 197, 16, 64)  0           ['block5_attn_value_bias[0][0]']
#
#  block5_attn_attention_scores (  (None, 16, 197, 197  0          ['block5_attn_pos_emb[0][0]']
#  Softmax)                       )
#
#  tf.compat.v1.transpose_22 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_28[0][0]']
#  pLambda)
#
#  lambda_11 (Lambda)             (None, 16, 197, 64)  0           ['block5_attn_attention_scores[0]
#                                                                  [0]',
#                                                                   'tf.compat.v1.transpose_22[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_23 (TFO  (None, 197, 16, 64)  0          ['lambda_11[0][0]']
#  pLambda)
#
#  tf.reshape_29 (TFOpLambda)     (None, 197, 1024)    0           ['tf.compat.v1.transpose_23[0][0]
#                                                                  ']
#
#  block5_attn_output (Dense)     (None, 197, 1024)    1049600     ['tf.reshape_29[0][0]']
#
#  block5_attn_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block5_attn_output[0][0]']
#  ne)
#
#  block5_attn_out (Add)          (None, 197, 1024)    0           ['block4_mlp_output[0][0]',
#                                                                   'block5_attn_gamma[0][0]']
#
#  block5_mlp_ln (LayerNormalizat  (None, 197, 1024)   2048        ['block5_attn_out[0][0]']
#  ion)
#
#  block5_mlp_dense_1 (Dense)     (None, 197, 4096)    4198400     ['block5_mlp_ln[0][0]']
#
#  block5_mlp_gelugelu (Activatio  (None, 197, 4096)   0           ['block5_mlp_dense_1[0][0]']
#  n)
#
#  block5_mlp_dense_2 (Dense)     (None, 197, 1024)    4195328     ['block5_mlp_gelugelu[0][0]']
#
# ...
#  block22_attn_query_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_22[0][0]']
#  ayer)
#
#  tf.reshape_111 (TFOpLambda)    (None, 197, 16, 64)  0           ['block22_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_88 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_111[0][0]']
#  pLambda)
#
#  tf.reshape_112 (TFOpLambda)    (None, 197, 16, 64)  0           ['tf.split_22[0][1]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_88[0][0]
#  a)                                                              ']
#
#  tf.compat.v1.transpose_89 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_112[0][0]']
#  pLambda)
#
#  lambda_44 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_22[0][0]',
#                                 )                                 'tf.compat.v1.transpose_89[0][0]
#                                                                  ']
#
#  block22_attn_value_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_22[0][2]']
#  ayer)
#
#  block22_attn_pos_emb (MultiHea  (None, 16, 197, 197  11712      ['lambda_44[0][0]']
#  dRelativePositionalEmbedding)  )
#
#  tf.reshape_113 (TFOpLambda)    (None, 197, 16, 64)  0           ['block22_attn_value_bias[0][0]']
#
#  block22_attn_attention_scores   (None, 16, 197, 197  0          ['block22_attn_pos_emb[0][0]']
#  (Softmax)                      )
#
#  tf.compat.v1.transpose_90 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_113[0][0]']
#  pLambda)
#
#  lambda_45 (Lambda)             (None, 16, 197, 64)  0           ['block22_attn_attention_scores[0
#                                                                  ][0]',
#                                                                   'tf.compat.v1.transpose_90[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_91 (TFO  (None, 197, 16, 64)  0          ['lambda_45[0][0]']
#  pLambda)
#
#  tf.reshape_114 (TFOpLambda)    (None, 197, 1024)    0           ['tf.compat.v1.transpose_91[0][0]
#                                                                  ']
#
#  block22_attn_output (Dense)    (None, 197, 1024)    1049600     ['tf.reshape_114[0][0]']
#
#  block22_attn_gamma (ChannelAff  (None, 197, 1024)   1024        ['block22_attn_output[0][0]']
#  ine)
#
#  block22_attn_out (Add)         (None, 197, 1024)    0           ['block21_mlp_output[0][0]',
#                                                                   'block22_attn_gamma[0][0]']
#
#  block22_mlp_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block22_attn_out[0][0]']
#  tion)
#
#  block22_mlp_dense_1 (Dense)    (None, 197, 4096)    4198400     ['block22_mlp_ln[0][0]']
#
#  block22_mlp_gelugelu (Activati  (None, 197, 4096)   0           ['block22_mlp_dense_1[0][0]']
#  on)
#
#  block22_mlp_dense_2 (Dense)    (None, 197, 1024)    4195328     ['block22_mlp_gelugelu[0][0]']
#
#  block22_mlp_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block22_mlp_dense_2[0][0]']
#  ne)
#
#  block22_mlp_output (Add)       (None, 197, 1024)    0           ['block22_attn_out[0][0]',
#                                                                   'block22_mlp_gamma[0][0]']
#
#  block23_attn_ln (LayerNormaliz  (None, 197, 1024)   2048        ['block22_mlp_output[0][0]']
#  ation)
#
#  block23_attn_qkv (Dense)       (None, 197, 3072)    3145728     ['block23_attn_ln[0][0]']
#
#  tf.reshape_115 (TFOpLambda)    (None, 197, 3072)    0           ['block23_attn_qkv[0][0]']
#
#  tf.split_23 (TFOpLambda)       [(None, 197, 1024),  0           ['tf.reshape_115[0][0]']
#                                  (None, 197, 1024),
#                                  (None, 197, 1024)]
#
#  block23_attn_query_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_23[0][0]']
#  ayer)
#
#  tf.reshape_116 (TFOpLambda)    (None, 197, 16, 64)  0           ['block23_attn_query_bias[0][0]']
#
#  tf.compat.v1.transpose_92 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_116[0][0]']
#  pLambda)
#
#  tf.reshape_117 (TFOpLambda)    (None, 197, 16, 64)  0           ['tf.split_23[0][1]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 16, 197, 64)  0          ['tf.compat.v1.transpose_92[0][0]
#  a)                                                              ']
#
#  tf.compat.v1.transpose_93 (TFO  (None, 16, 64, 197)  0          ['tf.reshape_117[0][0]']
#  pLambda)
#
#  lambda_46 (Lambda)             (None, 16, 197, 197  0           ['tf.math.multiply_23[0][0]',
#                                 )                                 'tf.compat.v1.transpose_93[0][0]
#                                                                  ']
#
#  block23_attn_value_bias (BiasL  (None, 197, 1024)   1024        ['tf.split_23[0][2]']
#  ayer)
#
#  block23_attn_pos_emb (MultiHea  (None, 16, 197, 197  11712      ['lambda_46[0][0]']
#  dRelativePositionalEmbedding)  )
#
#  tf.reshape_118 (TFOpLambda)    (None, 197, 16, 64)  0           ['block23_attn_value_bias[0][0]']
#
#  block23_attn_attention_scores   (None, 16, 197, 197  0          ['block23_attn_pos_emb[0][0]']
#  (Softmax)                      )
#
#  tf.compat.v1.transpose_94 (TFO  (None, 16, 197, 64)  0          ['tf.reshape_118[0][0]']
#  pLambda)
#
#  lambda_47 (Lambda)             (None, 16, 197, 64)  0           ['block23_attn_attention_scores[0
#                                                                  ][0]',
#                                                                   'tf.compat.v1.transpose_94[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_95 (TFO  (None, 197, 16, 64)  0          ['lambda_47[0][0]']
#  pLambda)
#
#  tf.reshape_119 (TFOpLambda)    (None, 197, 1024)    0           ['tf.compat.v1.transpose_95[0][0]
#                                                                  ']
#
#  block23_attn_output (Dense)    (None, 197, 1024)    1049600     ['tf.reshape_119[0][0]']
#
#  block23_attn_gamma (ChannelAff  (None, 197, 1024)   1024        ['block23_attn_output[0][0]']
#  ine)
#
#  block23_attn_out (Add)         (None, 197, 1024)    0           ['block22_mlp_output[0][0]',
#                                                                   'block23_attn_gamma[0][0]']
#
#  block23_mlp_ln (LayerNormaliza  (None, 197, 1024)   2048        ['block23_attn_out[0][0]']
#  tion)
#
#  block23_mlp_dense_1 (Dense)    (None, 197, 4096)    4198400     ['block23_mlp_ln[0][0]']
#
#  block23_mlp_gelugelu (Activati  (None, 197, 4096)   0           ['block23_mlp_dense_1[0][0]']
#  on)
#
#  block23_mlp_dense_2 (Dense)    (None, 197, 1024)    4195328     ['block23_mlp_gelugelu[0][0]']
#
#  block23_mlp_gamma (ChannelAffi  (None, 197, 1024)   1024        ['block23_mlp_dense_2[0][0]']
#  ne)
#
#  block23_mlp_output (Add)       (None, 197, 1024)    0           ['block23_attn_out[0][0]',
#                                                                   'block23_mlp_gamma[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 196, 1024)   0           ['block23_mlp_output[0][0]']
#  ingOpLambda)
#
#  tf.math.reduce_mean (TFOpLambd  (None, 1024)        0           ['tf.__operators__.getitem[0][0]'
#  a)                                                              ]
#
#  out_ln (LayerNormalization)    (None, 1024)         2048        ['tf.math.reduce_mean[0][0]']
#
#  dense_19 (Dense)               (None, 3)            3075        ['out_ln[0][0]']
#
# ==================================================================================================
# Total params: 303,408,643
# Trainable params: 8,401,923
# Non-trainable params: 295,006,720
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='sgd',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=4, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/4
# 2022-06-30 15:55:02.230203: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.6656
# 2022-06-30 15:56:02.581469: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 103s 9s/step - loss: 0.6643 - accuracy: 0.6656 - val_loss: 2.2142 - val_accuracy: 0.2920
# Epoch 2/4
# 10/10 [==============================] - 69s 7s/step - loss: 0.6500 - accuracy: 0.6372 - val_loss: 2.2119 - val_accuracy: 0.2920
# Epoch 3/4
# 10/10 [==============================] - 75s 8s/step - loss: 0.6544 - accuracy: 0.6341 - val_loss: 2.2651 - val_accuracy: 0.2920
# Epoch 4/4
# 10/10 [==============================] - 85s 9s/step - loss: 0.6491 - accuracy: 0.6782 - val_loss: 2.1953 - val_accuracy: 0.2920

# %%
COLOR = 'black'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR

def predict(model, image, correct_label):
    prediction = model.predict(np.array([image]))
    predicted_class = class_names[np.argmax(prediction)]

    show_image(image, class_names[correct_label], predicted_class)

def show_image(img, label, guess):
    plt.figure()
    plt.imshow(img, cmap=plt.cm.binary)
    plt.title("Excpected: " + label)
    plt.xlabel("Guess: " + guess)
    plt.colorbar()
    plt.grid(False)
    plt.show()

def get_number():
    while True:
        num = input("Pick a number: ")
    if num.isdigit():
        num = int(num)
        if 0 <= num <= 1000:
            return int(num)
    else:
        print("Try again...")


for num in range(0, 10):
    image = X_test[num]
    label = y_test[num]
    predict(mm, image, label)
# Out:
# 2022-06-30 16:09:34.201230: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [43], in <cell line: 31>()
#      32 image = X_test[num]
#      33 label = y_test[num]
# ---> 34 predict(mm, image, label)
#
# Input In [43], in predict(model, image, correct_label)
#       5 def predict(model, image, correct_label):
#       6     prediction = model.predict(np.array([image]))
# ----> 7     predicted_class = class_names[np.argmax(prediction)]
#       9     show_image(image, class_names[correct_label], predicted_class)
#
# IndexError: list index out of range

# %%
model = keras.Sequential()
a = layers.Dense(2, activation="relu")
display(a)
model.add(a)
model.add(layers.Dense(3, activation="relu"))
model.add(layers.Dense(4))
