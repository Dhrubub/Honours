# %%
import os

import tensorflow as tf
import tensorflow.keras as keras

from keras_cv_attention_models import beit, convnext, swin_transformer_v2, davit, mobilevit

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from PIL import Image
from collections import defaultdict
from tabulate import tabulate
import pickle

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score

from datetime import datetime
from time import time
from time import sleep
import pytz

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# orig_folder = "../datasets/original"
exp_folder = "./experiment"

# orig_dataset1 = os.path.join(orig_folder, "1")
# orig_dataset2 = os.path.join(orig_folder, "2/Training-validation")
# orig_dataset3 = os.path.join(orig_folder, "3")

exp_dataset1 = os.path.join(exp_folder, "1")
exp_dataset2 = os.path.join(exp_folder, "2")
exp_dataset3 = os.path.join(exp_folder, "3")

exp_dataset4 = os.path.join(exp_folder, "4")

exp_dataset5 = os.path.join(exp_folder, "5")

exp_dataset6 = os.path.join(exp_folder, "6")
exp_dataset7 = os.path.join(exp_folder, "7")
exp_dataset8 = os.path.join(exp_folder, "8")

CLASS_NAMES = ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']

RANDOM_STATE = 42

randomiser = np.random.RandomState(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

def timer(func):
    # This function shows the execution time of 
    # the function object passed
    def wrap_func(*args, **kwargs):
        t1 = time()
        result = func(*args, **kwargs)
        t2 = time()
        print(f'Function {func.__name__!r} executed in {(t2-t1):.4f}s')
        return result
    return wrap_func

# %%
"""
Gets the data from the specific path and stores the data as a tuple with its appropriate label
"""
def get_dataset(paths, class_names):
    full_data = []
    class_dict = {}
    for i, name in enumerate(class_names):
        class_dict[name] = i
    
    for path in paths:
        print(path)
        for d in class_names:
            # uncomment to use only four classes - for breastnet model
#             if d not in ['normal', 'csom', 'myringosclerosis', 'earwax']: continue
            dirpath = os.path.join(path, d)
            if not os.path.exists(dirpath): continue
            print(dirpath)
            image_files = [f for f in os.listdir(dirpath) if f.endswith(('.jpg', '.png', 'jpeg'))]
            label = d
            for img in image_files:
                image = Image.open(os.path.join(dirpath, img))

                image = np.asarray(image).astype(np.float32) / 255.0

                data = np.array([image, class_dict[label]], dtype=object)
                full_data.append(data)
    
    full_data = np.array(full_data)
    np.random.shuffle(full_data)
    return full_data

# %%
"""
Used to resize the image based on model input size
"""
def resize_image(image, size):
    image = tf.image.resize(np.asarray(image).astype('float32'), (size, size))
    return np.asarray(image).astype('float32')

# %%
# change base path depending on experiment
base_path = exp_dataset3

# uncomment depending on experiment
# class_names = ['normal', 'csom', 'myringosclerosis', 'earwax']

class_names = CLASS_NAMES

class_dict = {
    1: 'normal',
    2: 'aom',
    3: 'ome',
    4: 'csom',
    5: 'myringosclerosis',
    6: 'earwax',
    7: 'tube'
}

classes = [1, 4, 5, 6]
# classes = [2, 7]

classes = [1, 2, 3, 4, 5, 6, 7]

# classes = [1,3,7]

class_names = [class_dict[i] for i in classes]

validation_set = []
testing_set = []


if not base_path == (exp_dataset4) and not base_path == exp_dataset5 and False:
    class_names = [c for c in CLASS_NAMES if c in os.listdir(os.path.join(base_path, 'training'))]

    validation_set = get_dataset([os.path.join(base_path, 'validation')], class_names)
    testing_set = get_dataset([os.path.join(base_path, 'testing')], class_names)

elif base_path == exp_dataset5 and False:
    class_names = CLASS_NAMES
    validation_set = []
    testing_set = get_dataset([os.path.join(base_path, '1'), os.path.join(base_path, '2'), os.path.join(base_path, '3')], class_names)
else:
    # change start and end to save subsets of the dataset
    
    base_path = "./experiment"
    
    start = 1
    end = 4
    
    validation_paths = [os.path.join(base_path, f'{i}/validation') for i in range(start, end)]
    test_paths = [os.path.join(base_path, f'{i}/testing') for i in range(start, end)]

    validation_set = get_dataset(validation_paths, class_names)
    testing_set = get_dataset(test_paths, class_names)
# Out:
# ./experiment/1/validation
# ./experiment/1/validation/normal
# ./experiment/1/validation/ome
# ./experiment/1/validation/tube
# ./experiment/2/validation
# ./experiment/2/validation/normal
# ./experiment/2/validation/csom
# ./experiment/2/validation/myringosclerosis
# ./experiment/2/validation/earwax
# ./experiment/3/validation
# ./experiment/3/validation/normal
# ./experiment/3/validation/aom
# ./experiment/3/validation/csom
# ./experiment/3/validation/myringosclerosis
# ./experiment/3/validation/earwax
# ./experiment/3/validation/tube
# ./experiment/1/testing
# ./experiment/1/testing/normal
# ./experiment/1/testing/ome
# ./experiment/1/testing/tube
# ./experiment/2/testing
# ./experiment/2/testing/normal
# ./experiment/2/testing/csom
# ./experiment/2/testing/myringosclerosis
# ./experiment/2/testing/earwax
# ./experiment/3/testing
# ./experiment/3/testing/normal
# ./experiment/3/testing/aom
# ./experiment/3/testing/csom
# ./experiment/3/testing/myringosclerosis
# ./experiment/3/testing/earwax
# ./experiment/3/testing/tube

# %%
# Separate the full data containing images and labels inside tuples into a train and test set
X_val = np.array([x[0] for x in validation_set], dtype=object)
y_val = np.array([y[1] for y in validation_set], dtype=np.uint8)

X_test = np.array([x[0] for x in testing_set], dtype=object)
y_test = np.array([y[1] for y in testing_set], dtype=np.uint8)

# %%
# Used to check the sample size for the different classes
print(class_names)
print(np.bincount(y_val))
print(np.bincount(y_test))
print(sum(np.bincount(y_test)))
# Out:
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [93 11 18 28 25 36 11]
# [188  25  36  57  49  72  23]
# 450

# %%
"""
Takes the history from training the model and graphs accuracy vs epoch and loss vs epoch
"""
def draw_graph(history):

    if 'history' in history:
        history = history.history
        
    plt.figure(figsize=(8,5))
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    best_epoch = np.argmin(history['val_loss'])
    
    plt.axvline(x=best_epoch, color='r', linestyle='--')
    plt.text(min(best_epoch+1, 38), 0.7, f"best epoch = {best_epoch}")

    plt.show()
    
    plt.figure(figsize=(8,5))
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    best_epoch = np.argmin(history['val_loss'])
    
    
    plt.axvline(x=best_epoch, color='r', linestyle='--')
    plt.text(min(best_epoch+1, 38), 0.9, f"best epoch = {best_epoch}")

# %%
"""
Compute the statistics, binary accuracy, accuracy, sensitivity, specificity and ppv
"""

def get_metrics(matrix):
    b_acc = []
    acc = []
    sens = []
    spec = []
    ppv = []

    for i, c in enumerate(class_names[:len(matrix)]):
        TP = matrix[i][i]
        FN = matrix.sum(axis=1)[i] - TP
        FP = matrix.sum(axis=0)[i] - TP
        TN = matrix.sum() - TP - FN - FP
        
        # Only use classes with a support greater than 0
        if (matrix.sum(axis=1)[i]) < 1: continue

        b_acc.append((TP+TN) / (TP+FN+FP+TN))
        acc.append((TP) / (TP+FN+FP+TN))
        sens.append((TP) / (TP+FN))
        spec.append((TN) / (TN+FP))
        ppv.append((TP) / (TP + FP))

    print(f"b_acc: {np.nanmean(b_acc)}")
    print(f"acc: {np.sum(acc)}")
    print(f"sens: {np.nanmean(sens)}")
    print(f"spec: {np.nanmean(spec)}")
    print(f"ppv: {np.nanmean(ppv)}")
    f1 = 2*(np.nanmean(ppv)*np.nanmean(sens) / (np.nanmean(ppv) + np.nanmean(sens)))
    print(f"f1: {f1}")

# %%
"""
Show the statistics of the model
Shows the confusion matrics and the selected metrics
"""

def show_statistics(model, X_test=X_test, y_test=y_test):
    # predict on the testing set to obtain a probability for each class
    y_pred=model.predict(X_test)
#     print(y_pred[0])
    
#     Uncomment to see the top-2 accuracy probability and value
#     print(top_k_accuracy_score(y_test, y_pred, k=2))
#     print(top_k_accuracy_score(y_test, y_pred, k=2, normalize=False))
    
        # use the highest probability to obtain the actual prediction
    y_pred=np.argmax(y_pred,axis=1)
    
    # display confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    names = [class_names[i] for i in sorted(np.unique(y_test))]
    
#     print(np.unique(y_test))
#     names = class_names
#     print(names)
#     names = ['normal', 'aom', 'csom', 'myringosclerosis', 'earwax']
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                 display_labels=names)
    
    plt.rcParams["figure.figsize"] = (5,5)
    disp.plot(cmap="Greys", xticks_rotation="vertical")
    
    # Print table of metrics and evaluations
    print(classification_report(y_test, y_pred, target_names=names, zero_division=0))
    
    # Show model summary
#     model.summary()
    get_metrics(cm)

# %%
# the names of the models for the experiments
# though the names are the same right now, they don't need to be
# models = {
#     exp_dataset1: ['daViT_B', 'convBase', 'vgg19', 'MobileViT_S'],
#     exp_dataset2: ['daViT_B', 'convBase', 'vgg19', 'MobileViT_S'],
#     exp_dataset3: ['daViT_B', 'convBase', 'vgg19', 'MobileViT_S'],
#     exp_dataset4: ['daViT_B', 'convBase', 'vgg19', 'MobileViT_S']
# }


m = "daViT_B"
model_path = "./models/9"

# %%
# see the summary of a model

# base_path = base_path
# base_path = exp_dataset4

# base_path = model_path

# for m in models[base_path][3:4]:
#     print(m)
# model_path = base_path.replace('datasets/experiment', 'models')
model = keras.models.load_model(os.path.join(model_path, m), compile=False)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_pad (ZeroPadding2D)        (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 56, 56, 128)  18944       stem_pad[0][0]
# __________________________________________________________________________________________________
# stem_ln (LayerNormalization)    (None, 56, 56, 128)  256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stack1_block1_pre_attn_cpe_dw_p (None, 58, 58, 128)  0           stem_ln[0][0]
# __________________________________________________________________________________________________
# stack1_block1_pre_attn_cpe_dw_c (None, 56, 56, 128)  1280        stack1_block1_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack1_block1_pre_attn_cpe_outp (None, 56, 56, 128)  0           stem_ln[0][0]
#                                                                  stack1_block1_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack1_block1_attn_ln (LayerNor (None, 56, 56, 128)  256         stack1_block1_pre_attn_cpe_output
# __________________________________________________________________________________________________
# tf.reshape_168 (TFOpLambda)     (None, 7, 8, 896)    0           stack1_block1_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_120 (TFO (None, 8, 7, 896)    0           tf.reshape_168[0][0]
# __________________________________________________________________________________________________
# tf.reshape_169 (TFOpLambda)     (None, 7, 7, 128)    0           tf.compat.v1.transpose_120[0][0]
# __________________________________________________________________________________________________
# stack1_block1_attn_qkv (Dense)  (None, 7, 7, 384)    49536       tf.reshape_169[0][0]
# __________________________________________________________________________________________________
# tf.reshape_170 (TFOpLambda)     (None, 49, 384)      0           stack1_block1_attn_qkv[0][0]
# __________________________________________________________________________________________________
# tf.split_24 (TFOpLambda)        [(None, 49, 128), (N 0           tf.reshape_170[0][0]
# __________________________________________________________________________________________________
# tf.reshape_171 (TFOpLambda)     (None, 49, 4, 32)    0           tf.split_24[0][0]
# __________________________________________________________________________________________________
# tf.reshape_172 (TFOpLambda)     (None, 49, 4, 32)    0           tf.split_24[0][1]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_121 (TFO (None, 4, 49, 32)    0           tf.reshape_171[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_122 (TFO (None, 4, 32, 49)    0           tf.reshape_172[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 4, 49, 49)    0           tf.compat.v1.transpose_121[0][0]
#                                                                  tf.compat.v1.transpose_122[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 4, 49, 49)    0           lambda_48[0][0]
# __________________________________________________________________________________________________
# tf.reshape_173 (TFOpLambda)     (None, 49, 4, 32)    0           tf.split_24[0][2]
# __________________________________________________________________________________________________
# stack1_block1_attn_attention_sc (None, 4, 49, 49)    0           tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_123 (TFO (None, 4, 49, 32)    0           tf.reshape_173[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 4, 49, 32)    0           stack1_block1_attn_attention_scor
#                                                                  tf.compat.v1.transpose_123[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_124 (TFO (None, 49, 4, 32)    0           lambda_49[0][0]
# __________________________________________________________________________________________________
# tf.reshape_174 (TFOpLambda)     (None, 7, 7, 128)    0           tf.compat.v1.transpose_124[0][0]
# __________________________________________________________________________________________________
# stack1_block1_attn_output (Dens (None, 7, 7, 128)    16512       tf.reshape_174[0][0]
# __________________________________________________________________________________________________
# tf.reshape_175 (TFOpLambda)     (None, 8, 7, 896)    0           stack1_block1_attn_output[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_125 (TFO (None, 7, 8, 896)    0           tf.reshape_175[0][0]
# __________________________________________________________________________________________________
# tf.reshape_176 (TFOpLambda)     (None, 56, 56, 128)  0           tf.compat.v1.transpose_125[0][0]
# __________________________________________________________________________________________________
# stack1_block1_attn_out (Add)    (None, 56, 56, 128)  0           stack1_block1_pre_attn_cpe_output
#                                                                  tf.reshape_176[0][0]
# __________________________________________________________________________________________________
# stack1_block1_pre_ffn_cpe_dw_pa (None, 58, 58, 128)  0           stack1_block1_attn_out[0][0]
# __________________________________________________________________________________________________
# stack1_block1_pre_ffn_cpe_dw_co (None, 56, 56, 128)  1280        stack1_block1_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack1_block1_pre_ffn_cpe_outpu (None, 56, 56, 128)  0           stack1_block1_attn_out[0][0]
#                                                                  stack1_block1_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack1_block1_mlp_ln (LayerNorm (None, 56, 56, 128)  256         stack1_block1_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack1_block1_mlp_Dense_0 (Dens (None, 56, 56, 512)  66048       stack1_block1_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack1_block1_mlp_gelu (Activat (None, 56, 56, 512)  0           stack1_block1_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack1_block1_mlp_Dense_1 (Dens (None, 56, 56, 128)  65664       stack1_block1_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack1_block1_output (Add)      (None, 56, 56, 128)  0           stack1_block1_pre_ffn_cpe_output[
#                                                                  stack1_block1_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack1_block2_pre_attn_cpe_dw_p (None, 58, 58, 128)  0           stack1_block1_output[0][0]
# __________________________________________________________________________________________________
# stack1_block2_pre_attn_cpe_dw_c (None, 56, 56, 128)  1280        stack1_block2_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack1_block2_pre_attn_cpe_outp (None, 56, 56, 128)  0           stack1_block1_output[0][0]
#                                                                  stack1_block2_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack1_block2_attn_ln (LayerNor (None, 56, 56, 128)  256         stack1_block2_pre_attn_cpe_output
# __________________________________________________________________________________________________
# stack1_block2_channel_attn_qkv  (None, 56, 56, 384)  49536       stack1_block2_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.reshape_177 (TFOpLambda)     (None, 3136, 384)    0           stack1_block2_channel_attn_qkv[0]
# __________________________________________________________________________________________________
# tf.split_25 (TFOpLambda)        [(None, 3136, 128),  0           tf.reshape_177[0][0]
# __________________________________________________________________________________________________
# tf.reshape_178 (TFOpLambda)     (None, 3136, 4, 32)  0           tf.split_25[0][1]
# __________________________________________________________________________________________________
# tf.reshape_179 (TFOpLambda)     (None, 3136, 4, 32)  0           tf.split_25[0][2]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_126 (TFO (None, 4, 32, 3136)  0           tf.reshape_178[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_127 (TFO (None, 4, 3136, 32)  0           tf.reshape_179[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 4, 32, 32)    0           tf.compat.v1.transpose_126[0][0]
#                                                                  tf.compat.v1.transpose_127[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 4, 32, 32)    0           lambda_50[0][0]
# __________________________________________________________________________________________________
# tf.reshape_180 (TFOpLambda)     (None, 3136, 4, 32)  0           tf.split_25[0][0]
# __________________________________________________________________________________________________
# stack1_block2_channel_attn_atte (None, 4, 32, 32)    0           tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_128 (TFO (None, 4, 32, 3136)  0           tf.reshape_180[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 4, 32, 3136)  0           stack1_block2_channel_attn_attent
#                                                                  tf.compat.v1.transpose_128[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_129 (TFO (None, 3136, 4, 32)  0           lambda_51[0][0]
# __________________________________________________________________________________________________
# tf.reshape_181 (TFOpLambda)     (None, 56, 56, 128)  0           tf.compat.v1.transpose_129[0][0]
# __________________________________________________________________________________________________
# stack1_block2_channel_attn_outp (None, 56, 56, 128)  16512       tf.reshape_181[0][0]
# __________________________________________________________________________________________________
# stack1_block2_attn_out (Add)    (None, 56, 56, 128)  0           stack1_block2_pre_attn_cpe_output
#                                                                  stack1_block2_channel_attn_output
# __________________________________________________________________________________________________
# stack1_block2_pre_ffn_cpe_dw_pa (None, 58, 58, 128)  0           stack1_block2_attn_out[0][0]
# __________________________________________________________________________________________________
# stack1_block2_pre_ffn_cpe_dw_co (None, 56, 56, 128)  1280        stack1_block2_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack1_block2_pre_ffn_cpe_outpu (None, 56, 56, 128)  0           stack1_block2_attn_out[0][0]
#                                                                  stack1_block2_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack1_block2_mlp_ln (LayerNorm (None, 56, 56, 128)  256         stack1_block2_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack1_block2_mlp_Dense_0 (Dens (None, 56, 56, 512)  66048       stack1_block2_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack1_block2_mlp_gelu (Activat (None, 56, 56, 512)  0           stack1_block2_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack1_block2_mlp_Dense_1 (Dens (None, 56, 56, 128)  65664       stack1_block2_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack1_block2_output (Add)      (None, 56, 56, 128)  0           stack1_block2_pre_ffn_cpe_output[
#                                                                  stack1_block2_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack2_downsample_ln (LayerNorm (None, 56, 56, 128)  256         stack1_block2_output[0][0]
# __________________________________________________________________________________________________
# stack2_downsample_conv (Conv2D) (None, 28, 28, 256)  131328      stack2_downsample_ln[0][0]
# __________________________________________________________________________________________________
# stack2_block1_pre_attn_cpe_dw_p (None, 30, 30, 256)  0           stack2_downsample_conv[0][0]
# __________________________________________________________________________________________________
# stack2_block1_pre_attn_cpe_dw_c (None, 28, 28, 256)  2560        stack2_block1_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack2_block1_pre_attn_cpe_outp (None, 28, 28, 256)  0           stack2_downsample_conv[0][0]
#                                                                  stack2_block1_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack2_block1_attn_ln (LayerNor (None, 28, 28, 256)  512         stack2_block1_pre_attn_cpe_output
# __________________________________________________________________________________________________
# tf.reshape_182 (TFOpLambda)     (None, 7, 4, 1792)   0           stack2_block1_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_130 (TFO (None, 4, 7, 1792)   0           tf.reshape_182[0][0]
# __________________________________________________________________________________________________
# tf.reshape_183 (TFOpLambda)     (None, 7, 7, 256)    0           tf.compat.v1.transpose_130[0][0]
# __________________________________________________________________________________________________
# stack2_block1_attn_qkv (Dense)  (None, 7, 7, 768)    197376      tf.reshape_183[0][0]
# __________________________________________________________________________________________________
# tf.reshape_184 (TFOpLambda)     (None, 49, 768)      0           stack2_block1_attn_qkv[0][0]
# __________________________________________________________________________________________________
# tf.split_26 (TFOpLambda)        [(None, 49, 256), (N 0           tf.reshape_184[0][0]
# __________________________________________________________________________________________________
# tf.reshape_185 (TFOpLambda)     (None, 49, 8, 32)    0           tf.split_26[0][0]
# __________________________________________________________________________________________________
# tf.reshape_186 (TFOpLambda)     (None, 49, 8, 32)    0           tf.split_26[0][1]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_131 (TFO (None, 8, 49, 32)    0           tf.reshape_185[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_132 (TFO (None, 8, 32, 49)    0           tf.reshape_186[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 8, 49, 49)    0           tf.compat.v1.transpose_131[0][0]
#                                                                  tf.compat.v1.transpose_132[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 8, 49, 49)    0           lambda_52[0][0]
# __________________________________________________________________________________________________
# tf.reshape_187 (TFOpLambda)     (None, 49, 8, 32)    0           tf.split_26[0][2]
# __________________________________________________________________________________________________
# stack2_block1_attn_attention_sc (None, 8, 49, 49)    0           tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_133 (TFO (None, 8, 49, 32)    0           tf.reshape_187[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 8, 49, 32)    0           stack2_block1_attn_attention_scor
#                                                                  tf.compat.v1.transpose_133[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_134 (TFO (None, 49, 8, 32)    0           lambda_53[0][0]
# __________________________________________________________________________________________________
# tf.reshape_188 (TFOpLambda)     (None, 7, 7, 256)    0           tf.compat.v1.transpose_134[0][0]
# __________________________________________________________________________________________________
# stack2_block1_attn_output (Dens (None, 7, 7, 256)    65792       tf.reshape_188[0][0]
# __________________________________________________________________________________________________
# tf.reshape_189 (TFOpLambda)     (None, 4, 7, 1792)   0           stack2_block1_attn_output[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_135 (TFO (None, 7, 4, 1792)   0           tf.reshape_189[0][0]
# __________________________________________________________________________________________________
# tf.reshape_190 (TFOpLambda)     (None, 28, 28, 256)  0           tf.compat.v1.transpose_135[0][0]
# __________________________________________________________________________________________________
# stack2_block1_attn_out (Add)    (None, 28, 28, 256)  0           stack2_block1_pre_attn_cpe_output
#                                                                  tf.reshape_190[0][0]
# __________________________________________________________________________________________________
# stack2_block1_pre_ffn_cpe_dw_pa (None, 30, 30, 256)  0           stack2_block1_attn_out[0][0]
# __________________________________________________________________________________________________
# stack2_block1_pre_ffn_cpe_dw_co (None, 28, 28, 256)  2560        stack2_block1_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack2_block1_pre_ffn_cpe_outpu (None, 28, 28, 256)  0           stack2_block1_attn_out[0][0]
#                                                                  stack2_block1_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack2_block1_mlp_ln (LayerNorm (None, 28, 28, 256)  512         stack2_block1_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack2_block1_mlp_Dense_0 (Dens (None, 28, 28, 1024) 263168      stack2_block1_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack2_block1_mlp_gelu (Activat (None, 28, 28, 1024) 0           stack2_block1_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack2_block1_mlp_Dense_1 (Dens (None, 28, 28, 256)  262400      stack2_block1_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack2_block1_output (Add)      (None, 28, 28, 256)  0           stack2_block1_pre_ffn_cpe_output[
#                                                                  stack2_block1_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack2_block2_pre_attn_cpe_dw_p (None, 30, 30, 256)  0           stack2_block1_output[0][0]
# __________________________________________________________________________________________________
# stack2_block2_pre_attn_cpe_dw_c (None, 28, 28, 256)  2560        stack2_block2_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack2_block2_pre_attn_cpe_outp (None, 28, 28, 256)  0           stack2_block1_output[0][0]
#                                                                  stack2_block2_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack2_block2_attn_ln (LayerNor (None, 28, 28, 256)  512         stack2_block2_pre_attn_cpe_output
# __________________________________________________________________________________________________
# stack2_block2_channel_attn_qkv  (None, 28, 28, 768)  197376      stack2_block2_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.reshape_191 (TFOpLambda)     (None, 784, 768)     0           stack2_block2_channel_attn_qkv[0]
# __________________________________________________________________________________________________
# tf.split_27 (TFOpLambda)        [(None, 784, 256), ( 0           tf.reshape_191[0][0]
# __________________________________________________________________________________________________
# tf.reshape_192 (TFOpLambda)     (None, 784, 8, 32)   0           tf.split_27[0][1]
# __________________________________________________________________________________________________
# tf.reshape_193 (TFOpLambda)     (None, 784, 8, 32)   0           tf.split_27[0][2]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_136 (TFO (None, 8, 32, 784)   0           tf.reshape_192[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_137 (TFO (None, 8, 784, 32)   0           tf.reshape_193[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 8, 32, 32)    0           tf.compat.v1.transpose_136[0][0]
#                                                                  tf.compat.v1.transpose_137[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 8, 32, 32)    0           lambda_54[0][0]
# __________________________________________________________________________________________________
# tf.reshape_194 (TFOpLambda)     (None, 784, 8, 32)   0           tf.split_27[0][0]
# __________________________________________________________________________________________________
# stack2_block2_channel_attn_atte (None, 8, 32, 32)    0           tf.math.multiply_27[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_138 (TFO (None, 8, 32, 784)   0           tf.reshape_194[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 8, 32, 784)   0           stack2_block2_channel_attn_attent
#                                                                  tf.compat.v1.transpose_138[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_139 (TFO (None, 784, 8, 32)   0           lambda_55[0][0]
# __________________________________________________________________________________________________
# tf.reshape_195 (TFOpLambda)     (None, 28, 28, 256)  0           tf.compat.v1.transpose_139[0][0]
# __________________________________________________________________________________________________
# stack2_block2_channel_attn_outp (None, 28, 28, 256)  65792       tf.reshape_195[0][0]
# __________________________________________________________________________________________________
# stack2_block2_attn_out (Add)    (None, 28, 28, 256)  0           stack2_block2_pre_attn_cpe_output
#                                                                  stack2_block2_channel_attn_output
# __________________________________________________________________________________________________
# stack2_block2_pre_ffn_cpe_dw_pa (None, 30, 30, 256)  0           stack2_block2_attn_out[0][0]
# __________________________________________________________________________________________________
# stack2_block2_pre_ffn_cpe_dw_co (None, 28, 28, 256)  2560        stack2_block2_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack2_block2_pre_ffn_cpe_outpu (None, 28, 28, 256)  0           stack2_block2_attn_out[0][0]
#                                                                  stack2_block2_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack2_block2_mlp_ln (LayerNorm (None, 28, 28, 256)  512         stack2_block2_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack2_block2_mlp_Dense_0 (Dens (None, 28, 28, 1024) 263168      stack2_block2_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack2_block2_mlp_gelu (Activat (None, 28, 28, 1024) 0           stack2_block2_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack2_block2_mlp_Dense_1 (Dens (None, 28, 28, 256)  262400      stack2_block2_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack2_block2_output (Add)      (None, 28, 28, 256)  0           stack2_block2_pre_ffn_cpe_output[
#                                                                  stack2_block2_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack3_downsample_ln (LayerNorm (None, 28, 28, 256)  512         stack2_block2_output[0][0]
# __________________________________________________________________________________________________
# stack3_downsample_conv (Conv2D) (None, 14, 14, 512)  524800      stack3_downsample_ln[0][0]
# __________________________________________________________________________________________________
# stack3_block1_pre_attn_cpe_dw_p (None, 16, 16, 512)  0           stack3_downsample_conv[0][0]
# __________________________________________________________________________________________________
# stack3_block1_pre_attn_cpe_dw_c (None, 14, 14, 512)  5120        stack3_block1_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack3_block1_pre_attn_cpe_outp (None, 14, 14, 512)  0           stack3_downsample_conv[0][0]
#                                                                  stack3_block1_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack3_block1_attn_ln (LayerNor (None, 14, 14, 512)  1024        stack3_block1_pre_attn_cpe_output
# __________________________________________________________________________________________________
# tf.reshape_196 (TFOpLambda)     (None, 7, 2, 3584)   0           stack3_block1_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_140 (TFO (None, 2, 7, 3584)   0           tf.reshape_196[0][0]
# __________________________________________________________________________________________________
# tf.reshape_197 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.transpose_140[0][0]
# __________________________________________________________________________________________________
# stack3_block1_attn_qkv (Dense)  (None, 7, 7, 1536)   787968      tf.reshape_197[0][0]
# __________________________________________________________________________________________________
# tf.reshape_198 (TFOpLambda)     (None, 49, 1536)     0           stack3_block1_attn_qkv[0][0]
# __________________________________________________________________________________________________
# tf.split_28 (TFOpLambda)        [(None, 49, 512), (N 0           tf.reshape_198[0][0]
# __________________________________________________________________________________________________
# tf.reshape_199 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_28[0][0]
# __________________________________________________________________________________________________
# tf.reshape_200 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_28[0][1]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_141 (TFO (None, 16, 49, 32)   0           tf.reshape_199[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_142 (TFO (None, 16, 32, 49)   0           tf.reshape_200[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 16, 49, 49)   0           tf.compat.v1.transpose_141[0][0]
#                                                                  tf.compat.v1.transpose_142[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_28 (TFOpLambda (None, 16, 49, 49)   0           lambda_56[0][0]
# __________________________________________________________________________________________________
# tf.reshape_201 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_28[0][2]
# __________________________________________________________________________________________________
# stack3_block1_attn_attention_sc (None, 16, 49, 49)   0           tf.math.multiply_28[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_143 (TFO (None, 16, 49, 32)   0           tf.reshape_201[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 16, 49, 32)   0           stack3_block1_attn_attention_scor
#                                                                  tf.compat.v1.transpose_143[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_144 (TFO (None, 49, 16, 32)   0           lambda_57[0][0]
# __________________________________________________________________________________________________
# tf.reshape_202 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.transpose_144[0][0]
# __________________________________________________________________________________________________
# stack3_block1_attn_output (Dens (None, 7, 7, 512)    262656      tf.reshape_202[0][0]
# __________________________________________________________________________________________________
# tf.reshape_203 (TFOpLambda)     (None, 2, 7, 3584)   0           stack3_block1_attn_output[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_145 (TFO (None, 7, 2, 3584)   0           tf.reshape_203[0][0]
# __________________________________________________________________________________________________
# tf.reshape_204 (TFOpLambda)     (None, 14, 14, 512)  0           tf.compat.v1.transpose_145[0][0]
# __________________________________________________________________________________________________
# stack3_block1_attn_out (Add)    (None, 14, 14, 512)  0           stack3_block1_pre_attn_cpe_output
#                                                                  tf.reshape_204[0][0]
# __________________________________________________________________________________________________
# stack3_block1_pre_ffn_cpe_dw_pa (None, 16, 16, 512)  0           stack3_block1_attn_out[0][0]
# __________________________________________________________________________________________________
# stack3_block1_pre_ffn_cpe_dw_co (None, 14, 14, 512)  5120        stack3_block1_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack3_block1_pre_ffn_cpe_outpu (None, 14, 14, 512)  0           stack3_block1_attn_out[0][0]
#                                                                  stack3_block1_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack3_block1_mlp_ln (LayerNorm (None, 14, 14, 512)  1024        stack3_block1_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack3_block1_mlp_Dense_0 (Dens (None, 14, 14, 2048) 1050624     stack3_block1_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack3_block1_mlp_gelu (Activat (None, 14, 14, 2048) 0           stack3_block1_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack3_block1_mlp_Dense_1 (Dens (None, 14, 14, 512)  1049088     stack3_block1_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack3_block1_output (Add)      (None, 14, 14, 512)  0           stack3_block1_pre_ffn_cpe_output[
#                                                                  stack3_block1_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack3_block2_pre_attn_cpe_dw_p (None, 16, 16, 512)  0           stack3_block1_output[0][0]
# __________________________________________________________________________________________________
# stack3_block2_pre_attn_cpe_dw_c (None, 14, 14, 512)  5120        stack3_block2_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack3_block2_pre_attn_cpe_outp (None, 14, 14, 512)  0           stack3_block1_output[0][0]
#                                                                  stack3_block2_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack3_block2_attn_ln (LayerNor (None, 14, 14, 512)  1024        stack3_block2_pre_attn_cpe_output
# __________________________________________________________________________________________________
# stack3_block2_channel_attn_qkv  (None, 14, 14, 1536) 787968      stack3_block2_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.reshape_205 (TFOpLambda)     (None, 196, 1536)    0           stack3_block2_channel_attn_qkv[0]
# __________________________________________________________________________________________________
# tf.split_29 (TFOpLambda)        [(None, 196, 512), ( 0           tf.reshape_205[0][0]
# __________________________________________________________________________________________________
# tf.reshape_206 (TFOpLambda)     (None, 196, 16, 32)  0           tf.split_29[0][1]
# __________________________________________________________________________________________________
# tf.reshape_207 (TFOpLambda)     (None, 196, 16, 32)  0           tf.split_29[0][2]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_146 (TFO (None, 16, 32, 196)  0           tf.reshape_206[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_147 (TFO (None, 16, 196, 32)  0           tf.reshape_207[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 16, 32, 32)   0           tf.compat.v1.transpose_146[0][0]
#                                                                  tf.compat.v1.transpose_147[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_29 (TFOpLambda (None, 16, 32, 32)   0           lambda_58[0][0]
# __________________________________________________________________________________________________
# tf.reshape_208 (TFOpLambda)     (None, 196, 16, 32)  0           tf.split_29[0][0]
# __________________________________________________________________________________________________
# stack3_block2_channel_attn_atte (None, 16, 32, 32)   0           tf.math.multiply_29[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_148 (TFO (None, 16, 32, 196)  0           tf.reshape_208[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 16, 32, 196)  0           stack3_block2_channel_attn_attent
#                                                                  tf.compat.v1.transpose_148[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_149 (TFO (None, 196, 16, 32)  0           lambda_59[0][0]
# __________________________________________________________________________________________________
# tf.reshape_209 (TFOpLambda)     (None, 14, 14, 512)  0           tf.compat.v1.transpose_149[0][0]
# __________________________________________________________________________________________________
# stack3_block2_channel_attn_outp (None, 14, 14, 512)  262656      tf.reshape_209[0][0]
# __________________________________________________________________________________________________
# stack3_block2_attn_out (Add)    (None, 14, 14, 512)  0           stack3_block2_pre_attn_cpe_output
#                                                                  stack3_block2_channel_attn_output
# __________________________________________________________________________________________________
# stack3_block2_pre_ffn_cpe_dw_pa (None, 16, 16, 512)  0           stack3_block2_attn_out[0][0]
# __________________________________________________________________________________________________
# stack3_block2_pre_ffn_cpe_dw_co (None, 14, 14, 512)  5120        stack3_block2_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack3_block2_pre_ffn_cpe_outpu (None, 14, 14, 512)  0           stack3_block2_attn_out[0][0]
#                                                                  stack3_block2_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack3_block2_mlp_ln (LayerNorm (None, 14, 14, 512)  1024        stack3_block2_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack3_block2_mlp_Dense_0 (Dens (None, 14, 14, 2048) 1050624     stack3_block2_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack3_block2_mlp_gelu (Activat (None, 14, 14, 2048) 0           stack3_block2_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack3_block2_mlp_Dense_1 (Dens (None, 14, 14, 512)  1049088     stack3_block2_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack3_block2_output (Add)      (None, 14, 14, 512)  0           stack3_block2_pre_ffn_cpe_output[
#                                                                  stack3_block2_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack3_block3_pre_attn_cpe_dw_p (None, 16, 16, 512)  0           stack3_block2_output[0][0]
# __________________________________________________________________________________________________
# stack3_block3_pre_attn_cpe_dw_c (None, 14, 14, 512)  5120        stack3_block3_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack3_block3_pre_attn_cpe_outp (None, 14, 14, 512)  0           stack3_block2_output[0][0]
#                                                                  stack3_block3_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack3_block3_attn_ln (LayerNor (None, 14, 14, 512)  1024        stack3_block3_pre_attn_cpe_output
# __________________________________________________________________________________________________
# tf.reshape_210 (TFOpLambda)     (None, 7, 2, 3584)   0           stack3_block3_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_150 (TFO (None, 2, 7, 3584)   0           tf.reshape_210[0][0]
# __________________________________________________________________________________________________
# tf.reshape_211 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.transpose_150[0][0]
# __________________________________________________________________________________________________
# stack3_block3_attn_qkv (Dense)  (None, 7, 7, 1536)   787968      tf.reshape_211[0][0]
# __________________________________________________________________________________________________
# tf.reshape_212 (TFOpLambda)     (None, 49, 1536)     0           stack3_block3_attn_qkv[0][0]
# __________________________________________________________________________________________________
# tf.split_30 (TFOpLambda)        [(None, 49, 512), (N 0           tf.reshape_212[0][0]
# __________________________________________________________________________________________________
# tf.reshape_213 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_30[0][0]
# __________________________________________________________________________________________________
# tf.reshape_214 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_30[0][1]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_151 (TFO (None, 16, 49, 32)   0           tf.reshape_213[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_152 (TFO (None, 16, 32, 49)   0           tf.reshape_214[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 16, 49, 49)   0           tf.compat.v1.transpose_151[0][0]
#                                                                  tf.compat.v1.transpose_152[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_30 (TFOpLambda (None, 16, 49, 49)   0           lambda_60[0][0]
# __________________________________________________________________________________________________
# tf.reshape_215 (TFOpLambda)     (None, 49, 16, 32)   0           tf.split_30[0][2]
# __________________________________________________________________________________________________
# stack3_block3_attn_attention_sc (None, 16, 49, 49)   0           tf.math.multiply_30[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_153 (TFO (None, 16, 49, 32)   0           tf.reshape_215[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 16, 49, 32)   0           stack3_block3_attn_attention_scor
#                                                                  tf.compat.v1.transpose_153[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_154 (TFO (None, 49, 16, 32)   0           lambda_61[0][0]
# __________________________________________________________________________________________________
# ...
# stack3_block18_mlp_gelu (Activa (None, 14, 14, 2048) 0           stack3_block18_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack3_block18_mlp_Dense_1 (Den (None, 14, 14, 512)  1049088     stack3_block18_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack3_block18_output (Add)     (None, 14, 14, 512)  0           stack3_block18_pre_ffn_cpe_output
#                                                                  stack3_block18_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack4_downsample_ln (LayerNorm (None, 14, 14, 512)  1024        stack3_block18_output[0][0]
# __________________________________________________________________________________________________
# stack4_downsample_conv (Conv2D) (None, 7, 7, 1024)   2098176     stack4_downsample_ln[0][0]
# __________________________________________________________________________________________________
# stack4_block1_pre_attn_cpe_dw_p (None, 9, 9, 1024)   0           stack4_downsample_conv[0][0]
# __________________________________________________________________________________________________
# stack4_block1_pre_attn_cpe_dw_c (None, 7, 7, 1024)   10240       stack4_block1_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack4_block1_pre_attn_cpe_outp (None, 7, 7, 1024)   0           stack4_downsample_conv[0][0]
#                                                                  stack4_block1_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack4_block1_attn_ln (LayerNor (None, 7, 7, 1024)   2048        stack4_block1_pre_attn_cpe_output
# __________________________________________________________________________________________________
# tf.reshape_322 (TFOpLambda)     (None, 7, 1, 7168)   0           stack4_block1_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_230 (TFO (None, 1, 7, 7168)   0           tf.reshape_322[0][0]
# __________________________________________________________________________________________________
# tf.reshape_323 (TFOpLambda)     (None, 7, 7, 1024)   0           tf.compat.v1.transpose_230[0][0]
# __________________________________________________________________________________________________
# stack4_block1_attn_qkv (Dense)  (None, 7, 7, 3072)   3148800     tf.reshape_323[0][0]
# __________________________________________________________________________________________________
# tf.reshape_324 (TFOpLambda)     (None, 49, 3072)     0           stack4_block1_attn_qkv[0][0]
# __________________________________________________________________________________________________
# tf.split_46 (TFOpLambda)        [(None, 49, 1024), ( 0           tf.reshape_324[0][0]
# __________________________________________________________________________________________________
# tf.reshape_325 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_46[0][0]
# __________________________________________________________________________________________________
# tf.reshape_326 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_46[0][1]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_231 (TFO (None, 32, 49, 32)   0           tf.reshape_325[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_232 (TFO (None, 32, 32, 49)   0           tf.reshape_326[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 32, 49, 49)   0           tf.compat.v1.transpose_231[0][0]
#                                                                  tf.compat.v1.transpose_232[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_46 (TFOpLambda (None, 32, 49, 49)   0           lambda_92[0][0]
# __________________________________________________________________________________________________
# tf.reshape_327 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_46[0][2]
# __________________________________________________________________________________________________
# stack4_block1_attn_attention_sc (None, 32, 49, 49)   0           tf.math.multiply_46[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_233 (TFO (None, 32, 49, 32)   0           tf.reshape_327[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 32, 49, 32)   0           stack4_block1_attn_attention_scor
#                                                                  tf.compat.v1.transpose_233[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_234 (TFO (None, 49, 32, 32)   0           lambda_93[0][0]
# __________________________________________________________________________________________________
# tf.reshape_328 (TFOpLambda)     (None, 7, 7, 1024)   0           tf.compat.v1.transpose_234[0][0]
# __________________________________________________________________________________________________
# stack4_block1_attn_output (Dens (None, 7, 7, 1024)   1049600     tf.reshape_328[0][0]
# __________________________________________________________________________________________________
# tf.reshape_329 (TFOpLambda)     (None, 1, 7, 7168)   0           stack4_block1_attn_output[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_235 (TFO (None, 7, 1, 7168)   0           tf.reshape_329[0][0]
# __________________________________________________________________________________________________
# tf.reshape_330 (TFOpLambda)     (None, 7, 7, 1024)   0           tf.compat.v1.transpose_235[0][0]
# __________________________________________________________________________________________________
# stack4_block1_attn_out (Add)    (None, 7, 7, 1024)   0           stack4_block1_pre_attn_cpe_output
#                                                                  tf.reshape_330[0][0]
# __________________________________________________________________________________________________
# stack4_block1_pre_ffn_cpe_dw_pa (None, 9, 9, 1024)   0           stack4_block1_attn_out[0][0]
# __________________________________________________________________________________________________
# stack4_block1_pre_ffn_cpe_dw_co (None, 7, 7, 1024)   10240       stack4_block1_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack4_block1_pre_ffn_cpe_outpu (None, 7, 7, 1024)   0           stack4_block1_attn_out[0][0]
#                                                                  stack4_block1_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack4_block1_mlp_ln (LayerNorm (None, 7, 7, 1024)   2048        stack4_block1_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack4_block1_mlp_Dense_0 (Dens (None, 7, 7, 4096)   4198400     stack4_block1_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack4_block1_mlp_gelu (Activat (None, 7, 7, 4096)   0           stack4_block1_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack4_block1_mlp_Dense_1 (Dens (None, 7, 7, 1024)   4195328     stack4_block1_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack4_block1_output (Add)      (None, 7, 7, 1024)   0           stack4_block1_pre_ffn_cpe_output[
#                                                                  stack4_block1_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# stack4_block2_pre_attn_cpe_dw_p (None, 9, 9, 1024)   0           stack4_block1_output[0][0]
# __________________________________________________________________________________________________
# stack4_block2_pre_attn_cpe_dw_c (None, 7, 7, 1024)   10240       stack4_block2_pre_attn_cpe_dw_pad
# __________________________________________________________________________________________________
# stack4_block2_pre_attn_cpe_outp (None, 7, 7, 1024)   0           stack4_block1_output[0][0]
#                                                                  stack4_block2_pre_attn_cpe_dw_con
# __________________________________________________________________________________________________
# stack4_block2_attn_ln (LayerNor (None, 7, 7, 1024)   2048        stack4_block2_pre_attn_cpe_output
# __________________________________________________________________________________________________
# stack4_block2_channel_attn_qkv  (None, 7, 7, 3072)   3148800     stack4_block2_attn_ln[0][0]
# __________________________________________________________________________________________________
# tf.reshape_331 (TFOpLambda)     (None, 49, 3072)     0           stack4_block2_channel_attn_qkv[0]
# __________________________________________________________________________________________________
# tf.split_47 (TFOpLambda)        [(None, 49, 1024), ( 0           tf.reshape_331[0][0]
# __________________________________________________________________________________________________
# tf.reshape_332 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_47[0][1]
# __________________________________________________________________________________________________
# tf.reshape_333 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_47[0][2]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_236 (TFO (None, 32, 32, 49)   0           tf.reshape_332[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_237 (TFO (None, 32, 49, 32)   0           tf.reshape_333[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 32, 32, 32)   0           tf.compat.v1.transpose_236[0][0]
#                                                                  tf.compat.v1.transpose_237[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_47 (TFOpLambda (None, 32, 32, 32)   0           lambda_94[0][0]
# __________________________________________________________________________________________________
# tf.reshape_334 (TFOpLambda)     (None, 49, 32, 32)   0           tf.split_47[0][0]
# __________________________________________________________________________________________________
# stack4_block2_channel_attn_atte (None, 32, 32, 32)   0           tf.math.multiply_47[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_238 (TFO (None, 32, 32, 49)   0           tf.reshape_334[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 32, 32, 49)   0           stack4_block2_channel_attn_attent
#                                                                  tf.compat.v1.transpose_238[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_239 (TFO (None, 49, 32, 32)   0           lambda_95[0][0]
# __________________________________________________________________________________________________
# tf.reshape_335 (TFOpLambda)     (None, 7, 7, 1024)   0           tf.compat.v1.transpose_239[0][0]
# __________________________________________________________________________________________________
# stack4_block2_channel_attn_outp (None, 7, 7, 1024)   1049600     tf.reshape_335[0][0]
# __________________________________________________________________________________________________
# stack4_block2_attn_out (Add)    (None, 7, 7, 1024)   0           stack4_block2_pre_attn_cpe_output
#                                                                  stack4_block2_channel_attn_output
# __________________________________________________________________________________________________
# stack4_block2_pre_ffn_cpe_dw_pa (None, 9, 9, 1024)   0           stack4_block2_attn_out[0][0]
# __________________________________________________________________________________________________
# stack4_block2_pre_ffn_cpe_dw_co (None, 7, 7, 1024)   10240       stack4_block2_pre_ffn_cpe_dw_pad[
# __________________________________________________________________________________________________
# stack4_block2_pre_ffn_cpe_outpu (None, 7, 7, 1024)   0           stack4_block2_attn_out[0][0]
#                                                                  stack4_block2_pre_ffn_cpe_dw_conv
# __________________________________________________________________________________________________
# stack4_block2_mlp_ln (LayerNorm (None, 7, 7, 1024)   2048        stack4_block2_pre_ffn_cpe_output[
# __________________________________________________________________________________________________
# stack4_block2_mlp_Dense_0 (Dens (None, 7, 7, 4096)   4198400     stack4_block2_mlp_ln[0][0]
# __________________________________________________________________________________________________
# stack4_block2_mlp_gelu (Activat (None, 7, 7, 4096)   0           stack4_block2_mlp_Dense_0[0][0]
# __________________________________________________________________________________________________
# stack4_block2_mlp_Dense_1 (Dens (None, 7, 7, 1024)   4195328     stack4_block2_mlp_gelu[0][0]
# __________________________________________________________________________________________________
# stack4_block2_output (Add)      (None, 7, 7, 1024)   0           stack4_block2_pre_ffn_cpe_output[
#                                                                  stack4_block2_mlp_Dense_1[0][0]
# __________________________________________________________________________________________________
# pre_output_ln (LayerNormalizati (None, 7, 7, 1024)   2048        stack4_block2_output[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1024)         0           pre_output_ln[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          131200      avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 7)            903         dense_1[0][0]
# ==================================================================================================
# Total params: 87,061,511
# Trainable params: 87,061,511
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# change loop condition depending the model you want to test
# for m in models[base_path][3:4]:
#     model_path = base_path.replace('datasets/experiment', 'models')
    
    model = keras.models.load_model(os.path.join(model_path, m), compile=False)
    hist = np.load(os.path.join(model_path, m + '.npy'), allow_pickle='TRUE').item()
    
    # resize images according to input layer
    img_size = model.layers[0].input_shape[0][1]
    X_val2 = np.array([resize_image(x, img_size) for x in X_val])
    X_test2 = np.array([resize_image(x, img_size) for x in X_test])
    
    print(m)
    show_statistics(model, X_test2, y_test)
    
    
    draw_graph(hist)
# Out:
# daViT_B
#                   precision    recall  f1-score   support
#
#           normal       0.89      0.90      0.90       188
#              aom       0.64      0.72      0.68        25
#              ome       0.92      0.97      0.95        36
#             csom       0.98      0.81      0.88        57
# myringosclerosis       0.81      0.88      0.84        49
#           earwax       0.87      0.92      0.89        72
#             tube       1.00      0.83      0.90        23
#
#         accuracy                           0.88       450
#        macro avg       0.87      0.86      0.86       450
#     weighted avg       0.89      0.88      0.88       450
#
# b_acc: 0.9657142857142856
# acc: 0.88
# sens: 0.8597829399844581
# spec: 0.9769930174262347
# ppv: 0.8737935543171235
# f1: 0.8667316308680296

# %%
"""
Creates the gradcam heatmap using last convolutional layer of the model
Code retrieved from https://keras.io/examples/vision/grad_cam/
"""

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
import matplotlib.cm as cm
import colorsys
"""
Takes an image and calls make_gradcam_heatmap() to make a 
heatmap then superimposes it to original image
"""
def display_gradcam(img, heatmap, alpha=0.5):
    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)
    img = np.uint8(255 * img)

    
    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    
    si = []
    for j, y in enumerate(jet_heatmap):
        si.append([])
        for i, x in enumerate(jet_heatmap[j]):
            arr = jet_heatmap[j, i]
            hsv = colorsys.rgb_to_hsv(arr[0]/255.0, arr[1]/255.0, arr[2]/255.0)
            
            # removing non important colours
            if 150 < hsv[0]*360 < 250:
                si[j].append(arr * 0)
            else:
                si[j].append(arr * alpha)

    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = si + img

    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img, scale=True)

    # Display Grad CAM
    return superimposed_img

# %%
"""
Provide the index value of the specific class you want to see a visualisation of
i.e., a 'tube' class is index 6 in the variable CLASS_NAMES
The index value depends on the dataset and class names being used
"""
model = keras.models.load_model('./models/9/daViT_B', compile=False);

def find_id(idx, arr, s):
    for i in range(len(arr)):
        if arr[i] == idx: 
            if not i in s:
                return i
    return 0
    
s = set()
while True:
    x = int(input())
    if x == -1:
        break;
    
    num = find_id(x, y_test, s)
    s.add(num)
    img = X_test2[num]
    
#     change input shape as per model
    img = img.reshape((1, 224, 224, 3))
    
#     change layer name as per model
    heatmap = make_gradcam_heatmap(img, model, 'stack4_block2_output')
    print(class_names[y_test[num]], num)

    y_pred=model.predict(img)
    y_pred=np.argmax(y_pred,axis=1)[0]
    print("Predicted: " + class_names[y_pred])

    gradcam = display_gradcam(X_test2[num], heatmap, alpha=0.5)
    plt.imshow(gradcam)
    plt.show()
# Out:
# l
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c0a04c87e8c6> in <module>
#      15 s = set()
#      16 while True:
# ---> 17     x = int(input())
#      18     if x == -1:
#      19         break;
#
# ValueError: invalid literal for int() with base 10: 'l'

# %%
"""
Tests the model visualisation on some selected images
"""

# model = keras.models.load_model('./models/9/daViT_B', compile=False);

# get img size from model input layer
img_size = model.layers[0].input_shape[0][1]
CLASS_NAMES = ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
image_files = get_dataset(['./experiment/heatmap'], CLASS_NAMES)

classes = CLASS_NAMES
for data in image_files:
    image = data[0]
    label = CLASS_NAMES[data[1]]
    
    image = resize_image(image, img_size)
    
    img = image.reshape((1, img_size, img_size, 3))
    heatmap = make_gradcam_heatmap(img, model, 'stack4_block2_output')

    y_pred=model.predict(img)
    y_pred2=np.argmax(y_pred,axis=1)[0]
    print("Predicted: " + classes[y_pred2])
    print("Expected: " + label)
    print(classes)
    print([float(a)*100 for a in y_pred[0]])

    gradcam = display_gradcam(image, heatmap, alpha=1)
    
#     uncomment to show original image
#     plt.imshow(image)
#     plt.axis('off')
#     plt.imshow(gradcam) 
#     plt.show()

    plt.figure(figsize=(10, 5))

    # Plot the original image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis('off')
#     plt.title('Original Image')

    # Plot the GradCAM heatmap
    plt.subplot(1, 2, 2)
    plt.imshow(gradcam)
    plt.axis('off')
#     plt.title('GradCAM Heatmap')

    plt.subplots_adjust(wspace=0.01)
    # Add a caption for the combined image at the bottom
#     plt.suptitle(f"{label}", y=0.05, fontsize=16)

    plt.show()
# Out:
# ./experiment/heatmap
# ./experiment/heatmap/normal
# ./experiment/heatmap/aom
# ./experiment/heatmap/ome
# ./experiment/heatmap/csom
# ./experiment/heatmap/myringosclerosis
# ./experiment/heatmap/earwax
# ./experiment/heatmap/tube
# Predicted: normal
# Expected: normal
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [51.188451051712036, 43.221572041511536, 0.49086716026067734, 1.615656167268753, 0.3250254550948739, 2.2659512236714363, 0.8924746885895729]
# Predicted: earwax
# Expected: earwax
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [0.16895952867344022, 0.13632691698148847, 1.2644724920392036, 0.7276501972228289, 0.3007908584550023, 96.18397951126099, 1.217813417315483]
# Predicted: aom
# Expected: aom
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [3.020482510328293, 78.80263924598694, 1.025376096367836, 6.824137270450592, 1.1497053317725658, 3.876463696360588, 5.3011976182460785]
# Predicted: normal
# Expected: normal
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [98.63917827606201, 0.10584642877802253, 0.7604223676025867, 0.0286173599306494, 0.1084972987882793, 0.06861557485535741, 0.28881870675832033]
# Predicted: csom
# Expected: csom
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [15.343745052814484, 6.116855889558792, 0.5227812565863132, 61.837953329086304, 7.98509418964386, 6.4107827842235565, 1.7827799543738365]
# Predicted: normal
# Expected: tube
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [97.08684086799622, 0.8157988078892231, 0.10573854669928551, 0.10668640024960041, 0.3678978653624654, 1.4298297464847565, 0.08720208425074816]
# Predicted: csom
# Expected: csom
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [0.008380096551263705, 0.6225999910384417, 2.3274775594472885, 95.63145637512207, 0.3779335180297494, 0.2878030529245734, 0.7443531416356564]
# Predicted: myringosclerosis
# Expected: myringosclerosis
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [0.39099855348467827, 0.06521596806123853, 0.09878509445115924, 1.8578287214040756, 95.6449031829834, 1.808464154601097, 0.1338035101071]
# Predicted: normal
# Expected: normal
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [97.27789163589478, 0.040651875315234065, 0.03643027157522738, 0.040738945244811475, 2.518586441874504, 0.04075909673701972, 0.04493641608860344]
# Predicted: normal
# Expected: myringosclerosis
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [61.420828104019165, 7.399142533540726, 0.20275949500501156, 17.630741000175476, 10.69968268275261, 1.8287941813468933, 0.8180525153875351]
# Predicted: earwax
# Expected: earwax
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [0.5514323245733976, 0.34708918537944555, 0.39295339956879616, 0.14119615079835057, 0.15839668922126293, 97.42432832717896, 0.9845989756286144]
# Predicted: ome
# Expected: ome
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [1.7305320128798485, 0.4783755633980036, 96.56901955604553, 0.10461339261382818, 0.10332941310480237, 0.31698718667030334, 0.6971463561058044]
# Predicted: tube
# Expected: tube
# ['normal', 'aom', 'ome', 'csom', 'myringosclerosis', 'earwax', 'tube']
# [27.192503213882446, 1.4046140015125275, 10.075462609529495, 1.8605053424835205, 1.8136333674192429, 0.6522320210933685, 57.00104832649231]

# %%
"""
Loads the breastnet / omnet model to use for testing
The test set can only contain the classes - normal, aom, csom, earwax
"""


omnet_model_name = 'BREASTNET_FOLD_3.h5'
omnet_model = keras.models.load_model(os.path.join('../models', omnet_model_name), compile=False)

img_size = model.layers[0].input_shape[0][1]
X_val2 = np.array([resize_image(x, img_size) for x in X_val])
X_test2 = np.array([resize_image(x, img_size) for x in X_test])

print(omnet_model_name)
show_statistics(omnet_model, X_test2, y_test)
